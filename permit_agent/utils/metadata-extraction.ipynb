# %%
import os
import io
import base64

from pydantic import BaseModel, Field
from typing import List, Any
from pdf2image import convert_from_path

from openai import AzureOpenAI

from dotenv import load_dotenv

load_dotenv()

api_base = os.getenv("AZURE_OPENAI_ENDPOINT")
deployment_name = os.getenv("AZURE_OPENAI_DEPLOYMENT_NAME")

client = AzureOpenAI(
    base_url=f"{api_base}/openai/deployments/{deployment_name}",
    api_key=os.getenv("AZURE_OPENAI_API_KEY"),
    api_version=os.getenv("AZURE_OPENAI_API_VERSION"),
)

extraction_prompt = """
You are an expert in extracting metadata from permit images. Given an image of a permit, extract the following metadata fields:
- Issue Date
  - The date when the permit was issued, formatted as dd MMMM yyyy (e.g., 25 December 2023)
  - Use english month names only
- Expiration Date
  - The date when the permit expires, formatted as dd MMMM yyyy (e.g., 25 December 2024)
  - Use english month names only
- Permit Type: Permit type is categorized as PLO, KKPR/KKPRL, or Ijin Lingkungan
- Summary: A brief summary of the permit content in no more than 100 words.
  - Summarize the main points of the permit, including its purpose, scope, and any important conditions or requirements mentioned.

Return the extracted metadata in the JSON format. Do not include any additional text or explanations.
"""

class PermitMetadata(BaseModel):
    issue_date: str = Field(..., description="The date when the permit was issued.")
    expiration_date: str = Field(..., description="The date when the permit expires.")
    permit_type: str = Field(..., description="The type/category of the permit.")
    summary: str = Field(..., description="A brief summary of the permit content.")

def base64_encoded_image(image, format: str = 'JPEG') -> str:
    """
    Generate a base64 encoded string from image object.
    
    Args:
        image: Image object (e.g., PIL.Image).
        
    Returns:
        str: Base64 encoded string of the image.
    """

    buffer = io.BytesIO()
    image.save(buffer, format=format)
    buffer.seek(0)
    encoded_str = base64.b64encode(buffer.read()).decode('utf-8')
    buffer.close()

    image_data = f"data:image/{format.lower()};base64,{encoded_str}"

    return image_data

def create_message(system_prompt: str, image_content: List[Any]) -> dict:
    """
    Create a message payload for the chat API.

    Args:
        system_prompt (str): The system prompt to include in the message.
        image_content (List[Any]): The content to include in the message.

    Returns:
        dict: The message payload.
    """
    message = [
        {"role": "system", "content": system_prompt},
        {"role": "user", "content": [
            {
                "type" : "text",
                "text": "Extract the metadata from the permit image."
            }
            ]
        }
    ]

    for content in image_content:
        message[1]['content'].append({"type": "image_url", "image_url": {"url" : base64_encoded_image(content)}})

    return message

# %%
import instructor

instructor_client = instructor.from_provider("azure_openai/gpt-4o")

FILE_PATH = "data/folder/KPI_Permits/Sertifikat_PLO_SKPI/PLO RU II/PLO CDU KILANG SEI PAKNING.pdf"

images = convert_from_path(FILE_PATH)
message_payload = create_message(extraction_prompt, images)

user, completion = instructor_client.chat.completions.create_with_completion(
    messages=message_payload,
    response_model=PermitMetadata
)
# Out:
# INFO:instructor.auto_client:Initializing azure_openai provider with model gpt-4o
# INFO:instructor.auto_client:Client initialized
# INFO:httpx:HTTP Request: POST https://openai-permit.openai.azure.com/openai/deployments/gpt-4o/chat/completions?api-version=2024-02-01 "HTTP/1.1 200 OK"

# %%
user
# Out:
# PermitMetadata(issue_date='19 December 2022', expiration_date='18 July 2026', permit_type='PLO', summary='This permit approves the operational feasibility of the Crude Distillation Unit (CDU) at PT Kilang Pertamina Internasional, located in Bengkalis, Riau. The installation comprises crude oil-based processing facilities to produce intermediate products such as Naptha, Kero, ADO, and LSWR. The CDU satisfies inspection requirements, including technical standards, design limits (50000 BPSD capacity), and periodic technical inspections every 6 months for safety systems like fire protection, instrument systems, and temperature controls. Inspection activities and methods are detailed, emphasizing compliance with established safety and environmental regulations. The permit remains valid until 18 July 2026.')

# %%
from datetime import datetime
from pprint import pprint

metadata = {
    "file_path": FILE_PATH,
    "issue_date": datetime.strptime(user.issue_date, "%d %B %Y").strftime("%Y-%m-%d"),
    "expiration_date": datetime.strptime(user.expiration_date, "%d %B %Y").strftime("%Y-%m-%d"),
    "permit_type": user.permit_type,
    "summary": user.summary
}

pprint(metadata)
# Out:
# {'expiration_date': '2026-07-18',
#  'file_path': 'data/folder/KPI_Permits/Sertifikat_PLO_SKPI/PLO RU II/PLO CDU '
#               'KILANG SEI PAKNING.pdf',
#  'issue_date': '2022-12-19',
#  'permit_type': 'PLO',
#  'summary': 'The permit is approval for the operational feasibility of the '
#             'Crude Distillation Unit (CDU) by PT Kilang Pertamina '
#             'Internasional. It outlines design and operational specifications, '
#             'including technical standards, capacities, and safety protocols. '
#             'Inspections and risk evaluations are mandated, emphasizing '
#             'adherence to regulatory standards, regular equipment checks, and '
#             'risk mitigation measures to ensure safe and efficient operation. '
#             'Compliance with environmental guidelines is emphasized.'}

# %%
print(completion.usage)
# Out:
# CompletionUsage(completion_tokens=160, prompt_tokens=5771, total_tokens=5931, completion_tokens_details=CompletionTokensDetails(accepted_prediction_tokens=None, audio_tokens=0, reasoning_tokens=0, rejected_prediction_tokens=None), prompt_tokens_details=PromptTokensDetails(audio_tokens=0, cached_tokens=5760))

# %%
import logging
import asyncio

from tenacity import retry, wait_exponential, stop_after_attempt, before_sleep_log

logging.basicConfig(level=logging.INFO)

@retry(
    stop=stop_after_attempt(3),
    wait=wait_exponential(multiplier=1, min=4, max=10),
    before_sleep=before_sleep_log(logging.getLogger(), logging.WARNING)
)
async def process_permit_metadata_async(file_path: str):
    loop = asyncio.get_event_loop()
    images = await loop.run_in_executor(None, convert_from_path, file_path)
    message_payload = create_message(extraction_prompt, images)
    logging.info(f"Processing file: {file_path} with {len(images)} pages.")

    user, completion = await loop.run_in_executor(
        None,
        instructor_client.chat.completions.create_with_completion,
        message_payload,
        PermitMetadata
    )

    return {
        "file_path": file_path,
        "issue_date": datetime.strptime(user.issue_date, "%d %B %Y").strftime("%Y-%m-%d"),
        "expiration_date": datetime.strptime(user.expiration_date, "%d %B %Y").strftime("%Y-%m-%d"),
        "permit_type": user.permit_type,
        "summary": user.summary,
        "usage": completion.usage
    }

# %%
import os

folder_path = "data/folder"
file_list = []
for root, dirs, files in os.walk(folder_path):
    for file in files:
        if file.lower().endswith(".pdf"):
            file_list.append(os.path.join(root, file))

print(file_list)
# Out:
# ['data/folder/PGN_Permits/4. Perling_PGN/Persetujuan Lingkungan SOR 1/SK Persetujuan Lingkungan UKL-UPL Stasiun Gas Dumai.PDF', 'data/folder/PGN_Permits/4. Perling_PGN/PL Th 2023 - Jargas CGP/Perling - PKPLH  Jargas Kota Yogyakarta dan Kab Sleman.pdf', 'data/folder/PGN_Permits/4. Perling_PGN/Persetujuan Lingkungan PMO/PKPLH UKL UPL KIK-Mangkang, Kendal.pdf', 'data/folder/PGN_Permits/4. Perling_PGN/Persetujuan Lingkungan SOR 2/SK Persetujuan PKPLH Upgrading Offtake Garawangi.PDF', 'data/folder/PGN_Permits/4. Perling_PGN/Persetujuan Lingkungan SOR 2/SK Persetujuan PKPLH Upgrading Offtake Sunyaragi.PDF', 'data/folder/PGN_Permits/4. Perling_PGN/Persetujuan Lingkungan SOR 2/SK Persling UKL-UPL Cabang Jkt.pdf', 'data/folder/PGN_Permits/4. Perling_PGN/Persetujuan Lingkungan SOR 2/SK Persetujuan Lingkungan UKL-UPL Cabang Bogor.PDF', 'data/folder/PGN_Permits/4. Perling_PGN/Persetujuan Lingkungan SOR 2/SK Persetujuan SKKL AMDAL PDJB.PDF', 'data/folder/PGN_Permits/4. Perling_PGN/Persetujuan Lingkungan SOR 3/SK Persetujuan Lingkungan UKL-UPL Husky Oil (St Gas Semare).pdf', 'data/folder/PGN_Permits/2. KKPR-L_PGN/KKPR TERBIT JARGAS MANDIRI- CGP/KKPR Jargas Kota Bandar Lampung.pdf', 'data/folder/PGN_Permits/2. KKPR-L_PGN/KKPR TERBIT JARGAS MANDIRI- CGP/KKKPR Jargas Kota Dumai.pdf', 'data/folder/PGN_Permits/2. KKPR-L_PGN/KKPR Non Cluster PMO/KKPR_Hotel Ratna_Sukabumi_Probolinggo.pdf', 'data/folder/PGN_Permits/2. KKPR-L_PGN/KKPR Non Cluster PMO/KKPR Wijayakusuma.pdf', 'data/folder/PGN_Permits/2. KKPR-L_PGN/KKPR Non Cluster PMO/KKPR_Danau Indah_Bekasi Barat.pdf', 'data/folder/PGN_Permits/2. KKPR-L_PGN/KKPRL/KKPRL_Pembangunan Terminal Khusus_Teluk Bima_Bima.pdf', 'data/folder/PGN_Permits/2. KKPR-L_PGN/KKPRL/KKPRL_Pembangunan Terminal Khusus_Laut Flores_Sumbawa.pdf', 'data/folder/PGN_Permits/2. KKPR-L_PGN/KKPRL/KKPRL_Pembangunan Terminal Khusus_Laut Flores_Manggarai Barat.pdf', 'data/folder/PGN_Permits/2. KKPR-L_PGN/KKPRL/KKPRL_Pembangunan Terminal Khusus Selat Lombok_Lombok Barat.pdf', 'data/folder/PGN_Permits/2. KKPR-L_PGN/KKPR Cluster PMO/KKPR Cluster Kota Bekasi.pdf', 'data/folder/PGN_Permits/2. KKPR-L_PGN/KKPR Cluster PMO/KKPR Cluster Kota Jakarta Barat.pdf', 'data/folder/PGN_Permits/3. PLO_PGN/PLO_Proyek_CA_2017-2022_PMO/PLO 11 Cluster 2021 (CA tahun 2020)/6NASKA~1.PDF', 'data/folder/PGN_Permits/3. PLO_PGN/PLO_Proyek_CA_2017-2022_PMO/PLO 11 Cluster 2021 (CA tahun 2020)/3NASKA~1.PDF', 'data/folder/PGN_Permits/3. PLO_PGN/PLO_Proyek_CA_2017-2022_PMO/PLO 11 Cluster 2021 (CA tahun 2020)/11NASK~1.PDF', 'data/folder/PGN_Permits/3. PLO_PGN/PLO_Proyek_CA_2017-2022_PMO/PLO 11 Cluster 2021 (CA tahun 2020)/4NASKA~1.PDF', 'data/folder/PGN_Permits/3. PLO_PGN/PLO_Proyek_CA_2017-2022_PMO/PLO 11 Cluster 2021 (CA tahun 2020)/1NASKA~1.PDF', 'data/folder/PGN_Permits/3. PLO_PGN/PLO_Proyek_CA_2017-2022_PMO/PLO 11 Cluster 2021 (CA tahun 2020)/10NASK~1.PDF', 'data/folder/PGN_Permits/3. PLO_PGN/PLO_Proyek_CA_2017-2022_PMO/PLO 11 Cluster 2021 (CA tahun 2020)/9NASKA_1.PDF', 'data/folder/PGN_Permits/3. PLO_PGN/PLO_Proyek_CA_2017-2022_PMO/PLO 11 Cluster 2021 (CA tahun 2020)/2NASKA~1.PDF', 'data/folder/PGN_Permits/3. PLO_PGN/PLO_Proyek_CA_2017-2022_PMO/PLO 11 Cluster 2021 (CA tahun 2020)/7NASKA~1.PDF', 'data/folder/PGN_Permits/3. PLO_PGN/PLO_Proyek_CA_2017-2022_PMO/PLO 11 Cluster 2021 (CA tahun 2020)/5NASKA~1.PDF', 'data/folder/PGN_Permits/3. PLO_PGN/PLO_Proyek_CA_2017-2022_PMO/PLO 11 Cluster 2021 (CA tahun 2020)/8NASKA~1.PDF', 'data/folder/PGN_Permits/3. PLO_PGN/PLO_Proyek_CA_2017-2022_PMO/PLO 13 Cluster 2020 (CA tahun 2017-2019)/PLO PMO Cluster Bogor.pdf', 'data/folder/PGN_Permits/3. PLO_PGN/PLO Proyek Transmisi-PMO/PLO Kendal.pdf', 'data/folder/PGN_Permits/3. PLO_PGN/PLO_SOR1-3/PLO SOR 1/PLO PGN 2023 AREA DUMAI.pdf', 'data/folder/PGN_Permits/3. PLO_PGN/PLO_SOR1-3/PLO SOR 1/PLO PGN 2023 AREA PEKANBARU.pdf', 'data/folder/PGN_Permits/3. PLO_PGN/PLO_SOR1-3/PLO SOR 1/PLO PGN 2023 AREA LAMPUNG.pdf', 'data/folder/PGN_Permits/3. PLO_PGN/PLO_SOR1-3/PLO SOR 1/PLO PGN 2023 AREA ...

# %%
from PyPDF2 import PdfReader

file_pages = []

def count_pdf_pages(file_path):
    reader = PdfReader(file_path)
    return len(reader.pages)

for file_path in file_list:
    file_pages.append(count_pdf_pages(file_path))

# %%
long_files = []

for file_path, num_pages in zip(file_list, file_pages):
    if num_pages > 10:
        print(f"File {file_path} has {num_pages} pages.")
        long_files.append(file_path)

print(f"Files with more than 10 pages: {len(long_files)}")
# Out:
# File data/folder/PGN_Permits/4. Perling_PGN/Persetujuan Lingkungan SOR 1/SK Persetujuan Lingkungan UKL-UPL Stasiun Gas Dumai.PDF has 37 pages.
# File data/folder/PGN_Permits/4. Perling_PGN/PL Th 2023 - Jargas CGP/Perling - PKPLH  Jargas Kota Yogyakarta dan Kab Sleman.pdf has 58 pages.
# File data/folder/PGN_Permits/4. Perling_PGN/Persetujuan Lingkungan PMO/PKPLH UKL UPL KIK-Mangkang, Kendal.pdf has 31 pages.
# File data/folder/PGN_Permits/4. Perling_PGN/Persetujuan Lingkungan SOR 2/SK Persetujuan PKPLH Upgrading Offtake Garawangi.PDF has 24 pages.
# File data/folder/PGN_Permits/4. Perling_PGN/Persetujuan Lingkungan SOR 2/SK Persetujuan PKPLH Upgrading Offtake Sunyaragi.PDF has 52 pages.
# File data/folder/PGN_Permits/4. Perling_PGN/Persetujuan Lingkungan SOR 2/SK Persling UKL-UPL Cabang Jkt.pdf has 48 pages.
# File data/folder/PGN_Permits/4. Perling_PGN/Persetujuan Lingkungan SOR 2/SK Persetujuan Lingkungan UKL-UPL Cabang Bogor.PDF has 17 pages.
# File data/folder/PGN_Permits/4. Perling_PGN/Persetujuan Lingkungan SOR 2/SK Persetujuan SKKL AMDAL PDJB.PDF has 31 pages.
# File data/folder/PGN_Permits/4. Perling_PGN/Persetujuan Lingkungan SOR 3/SK Persetujuan Lingkungan UKL-UPL Husky Oil (St Gas Semare).pdf has 32 pages.
# File data/folder/PGN_Permits/2. KKPR-L_PGN/KKPR TERBIT JARGAS MANDIRI- CGP/KKPR Jargas Kota Bandar Lampung.pdf has 12 pages.
# File data/folder/PGN_Permits/2. KKPR-L_PGN/KKPR Cluster PMO/KKPR Cluster Kota Jakarta Barat.pdf has 17 pages.
# File data/folder/PGN_Permits/3. PLO_PGN/PLO_Proyek_CA_2017-2022_PMO/PLO 11 Cluster 2021 (CA tahun 2020)/6NASKA~1.PDF has 198 pages.
# File data/folder/PGN_Permits/3. PLO_PGN/PLO_Proyek_CA_2017-2022_PMO/PLO 11 Cluster 2021 (CA tahun 2020)/3NASKA~1.PDF has 118 pages.
# File data/folder/PGN_Permits/3. PLO_PGN/PLO_Proyek_CA_2017-2022_PMO/PLO 11 Cluster 2021 (CA tahun 2020)/11NASK~1.PDF has 198 pages.
# File data/folder/PGN_Permits/3. PLO_PGN/PLO_Proyek_CA_2017-2022_PMO/PLO 11 Cluster 2021 (CA tahun 2020)/4NASKA~1.PDF has 94 pages.
# File data/folder/PGN_Permits/3. PLO_PGN/PLO_Proyek_CA_2017-2022_PMO/PLO 11 Cluster 2021 (CA tahun 2020)/1NASKA~1.PDF has 31 pages.
# File data/folder/PGN_Permits/3. PLO_PGN/PLO_Proyek_CA_2017-2022_PMO/PLO 11 Cluster 2021 (CA tahun 2020)/10NASK~1.PDF has 91 pages.
# File data/folder/PGN_Permits/3. PLO_PGN/PLO_Proyek_CA_2017-2022_PMO/PLO 11 Cluster 2021 (CA tahun 2020)/9NASKA_1.PDF has 197 pages.
# File data/folder/PGN_Permits/3. PLO_PGN/PLO_Proyek_CA_2017-2022_PMO/PLO 11 Cluster 2021 (CA tahun 2020)/2NASKA~1.PDF has 71 pages.
# File data/folder/PGN_Permits/3. PLO_PGN/PLO_Proyek_CA_2017-2022_PMO/PLO 11 Cluster 2021 (CA tahun 2020)/7NASKA~1.PDF has 198 pages.
# File data/folder/PGN_Permits/3. PLO_PGN/PLO_Proyek_CA_2017-2022_PMO/PLO 11 Cluster 2021 (CA tahun 2020)/5NASKA~1.PDF has 93 pages.
# File data/folder/PGN_Permits/3. PLO_PGN/PLO_Proyek_CA_2017-2022_PMO/PLO 11 Cluster 2021 (CA tahun 2020)/8NASKA~1.PDF has 76 pages.
# File data/folder/PGN_Permits/3. PLO_PGN/PLO Proyek Transmisi-PMO/PLO Kendal.pdf has 313 pages.
# File data/folder/PGN_Permits/3. PLO_PGN/PLO_SOR1-3/PLO SOR 1/PLO PGN 2023 AREA DUMAI.pdf has 91 pages.
# File data/folder/PGN_Permits/3. PLO_PGN/PLO_SOR1-3/PLO SOR 1/PLO PGN 2023 AREA PEKANBARU.pdf has 24 pages.
# File data/folder/PGN_Permits/3. PLO_PGN/PLO_SOR1-3/PLO SOR 1/PLO PGN 2023 AREA LAMPUNG.pdf has 63 pages.
# File data/folder/PGN_Permits/3. PLO_PGN/PLO_SOR1-3/PLO SOR 1/PLO PGN 2023 AREA PALEMBANG.pdf has 50 pages.
# File data/folder/PGN_Permits/3. PLO_PGN/PLO_SOR1-3/PLO SOR 1/PLO PGN 2023 AREA MEDAN.pdf has 151 pages.
# File data/folder/PGN_Permits/3. PLO_PGN/PLO_SOR1-3/PLO SOR 1/PLO PGN 2023 AREA BATAM.pdf has 147 pages.
# File data/folder/KPI_Permits/Sertifikat_PLO_SKPI/PLO RU II/PLO 9 Pipa Penyalur.pdf has 274 pages.
# File data/folder/KPI_Permits/Sertifikat_PLO_SKPI/PLO RU II/PLO HSC UTL.pdf has 37 pages.
# File data/folder/KPI_Permits/Sertifikat_PLO_SKPI/PLO RU II/PLO PT KPI RU II Dumai.pdf has 18 pages.
# File data/folder/KPI_Permits/Sertifikat_PLO_SKPI/PLO RU VI/PLO KPOC.pdf has 131 pages.
# File data/folder/KPI_Permits/Sertifikat_PLO_SKPI/PLO RU VI/PLO CDU.pdf has 96 pages.
# File data/folder/KPI_Permits/Sertifikat_PLO_SKPI/PLO RU IV/20 - Nomor 397_48-4_PLO_DMT_2024 Instalasi Kilang I.pdf has 13 pages.
# File data/folder/KPI_Permits/Sertifikat_PLO_SKPI/PLO RU IV/21 - Nomor 392_48-4_PLO_DMT_2024 Instalasi Kilang II.pdf has 14 pages.
# File data/folder/KPI_Permits/Sertifikat_PLO_SKPI/PLO RU V/naskah-dinas-903635_21082024.pdf has 49 pages.
# File data/folder/KPI_Permits/Sertifikat_PLO_SKPI/PLO RU V/PLO Pipa Penyalur Penajam-Balikpapan.pdf has 103 pages.
# File data/folder/KPI_Permits/Sertifikat_PLO_SKPI/PLO RU V/1381_SKPI_PLO PIPA PENYALUR ø30in Jalur SPM A&B ke Terminal Lawe-Lawe (Offshore-onshore).pdf has 131 pages.
# File data/folder/KPI_Permits/Sertifikat_PLO_SKPI/PLO RU V/naskah-dinas-895164_15082024-1_240816_111343.pdf has 57 pages.
# File data/folder/KPI_Permits/Sertifikat_PLO_SKPI/PLO RU V/PLO Utilities New.pdf has 367 pages.
# File data/folder/KPI_Permits/Sertifikat_PLO_SKPI/PLO RU III/PLO RU III Plaju Sumsel_MASTER FILE PLO & COI 2022.pdf has 542 pages.
# File data/folder/KPI_Permits/KKPR_KKPRL/RU V Balikpapan/PKKPRL Teluk Makasan dan Balikpapan RU V Balikpapan.pdf has 11 pages.
# File data/folder/KPI_Permits/PERLING/RU III Plaju/PT.KILANG PERTAMINA INTERNASIONAL (SK.314) RU III Plaju kelayakan.pdf has 100 pages.
# File data/folder/KPI_Permits/PERLING/RU III Plaju/3. PL RU III PLAJU.pdf has 82 pages.
# File data/folder/KPI_Permits/PERLING/RU VII Kasim/7. PL RU VII KASIM.pdf has 89 pages.
# File data/folder/KPI_Permits/PERLING/RU VII Kasim/PT. KILANG PERTAMINA INTERNASIONAL RU VII Kasim (SK.207) kelayakan.pdf has 89 pages.
# File data/folder/KPI_Permits/PERLING/RU II Dumai & Sei Pakning/RU II SPK/SK PERSETUJUAN DELH RU II SPK NO 993.pdf has 57 pages.
# File data/folder/KPI_Permits/PERLING/RU II Dumai & Sei Pakning/RU II Dumai/RU II Dumai/RU II DUMAI_SK 1358 2021.pdf has 16 pages.
# File data/folder/KPI_Permits/PERLING/RU VI Balongan/RU VI BALONGAN_SK 1299 2021.pdf has 22 pages.
# File data/folder/KPI_Permits/PERLING/RU VI Balongan/RU VI BALONGAN_SK 1299 2021_LAMPIRAN I.pdf has 126 pages.
# File data/folder/KPI_Permits/PERLING/RU V Balikpapan/RU V Balikpapan_SK 1019 2021.pdf has 17 pages.
# File data/folder/KPI_Permits/PERLING/RU V Balikpapan/RU V Balikpapan_SK 1019 2021_Lampiran I.pdf has 219 pages.
# File data/folder/KPI_Permits/PERLING/RU IV Cilacap/4. PL RU IV CILACAP.pdf has 18 pages.
# File data/folder/KPI_Permits/PERLING/RU IV Cilacap/RU IV Cilacap/Lampiran 1 SK 412_RU IV Cilacap.pdf has 174 pages.
# File data/folder/KPI_Permits/PERLING/RU IV Cilacap/RU IV Cilacap/Lampiran 2-6 SK 412_RU IV Cilacap.pdf has 57 pages.
# File data/folder/KPI_Permits/PERLING/RU IV Cilacap/RU IV Cilacap/SKKL No. 412_RU IV Cilacap.pdf has 22 pages.
# File data/folder/SHU_Permits/Regional_1/Zona_1/PT Pertamina EP Asset 1 - Field Rantau/2. Izin Lingkungan SKKL No. 361_MenLHK_SETJEN_PLA.4_4_2022.pdf has 84 pages.
# File data/folder/SHU_Permits/Regional_1/Zona_1/PHE NSO (Eks. Mobil Exploration Indonesia Inc.)/Dokumen Lingkungan_Izin Lingkungan/SKKL - SK.319_MENLH_SETJEN_PLA.4_4_2023.pdf has 46 pages.
# File data/folder/SHU_Permits/Regional_1/Zona_1/PHE Jambi Merang/Dokumen Lingkungan_Izin Lingkungan/8. SK.391_Menlhk_Setjen_PLA.4_9_2018 - Izin Lingkungan 391 2018.pdf has 77 pages.
# File data/folder/SHU_Permits/Regional_1/Zona_1/PT Pertamina EP Asset 1 - Field Jambi/Dokumen Lingkungan_Izin Lingkungan/29. SK No 1103 Tahun 2024 Adendum andal RKL RPL PE Jambi Field.pdf has 184 pages.
# File data/folder/SHU_Permits/Regional_1/Zona_1/PT Pertamina EP Asset 1 - Field Pangkalan Susu/Dokumen Lingkungan_Izin Lingkungan/3. Izin Lingkungan SKKL No. 361_MenLHK_SETJEN_PLA.4_4_2022.pdf has 84 pages.
# File data/folder/SHU_Permits/Regional_1/Zona_1/PT Pertamina EP Asset 1 - Field Pangkalan Susu/PLB3/Lampiran IV Rintek_SK.No 361_MenLHK_SETJEN_PLA.4_4_2022(TPS).pdf has 12 pages.
# File data/folder/PPN_Permits/Sertifikat_PLO/DPPU Kalimarau.pdf has 65 pages.
# File data/folder/PPN_Permits/Sertifikat_PLO/FT Malang.pdf has 56 pages.
# File data/folder/PPN_Permits/Sertifikat_PLO/FT Serui.pdf has 30 pages.
# File data/folder/PPN_Permits/Sertifikat_PLO/FT Tasikmalaya.pdf has 68 pages.
# File data/folder/PPN_Permits/Sertifikat_PLO/DPPU Ahmad Yani (Lama).pdf has 40 pages.
# File data/folder/PPN_Permits/Sertifikat_PLO/Pipa Penyalur Tuban - Surabaya.pdf has 636 pages.
# File data/folder/PPN_Permits/Sertifikat_PLO/DPPU Ahmad Yani Baru.pdf has 276 pages.
# File data/folder/PPN_Permits/Sertifikat_PLO/DPPU Sentani, Babullah, Pattimura, Mopah, Frans Kaisiepo, Rendani, DEO.pdf has 145 pages.
# File data/folder/PPN_Permits/Sertifikat_PLO/Pipeline Perak - Juanda.pdf has 27 pages.
# File data/folder/PPN_Permits/Sertifikat_PLO/Sertifikat_PLO_sharing/PLO FT Cikampek.pdf has 79 pages.
# File data/folder/PPN_Permits/Sertifikat_PLO/Sertifikat_PLO_sharing/PLO Integrated Terminal Makassar (Fuel).pdf has 117 pages.
# File data/folder/PPN_Permits/Sertifikat_PLO/Sertifikat_PLO_sharing/PLO Integrated Terminal Makassar (LPG).pdf has 104 pages.
# File data/folder/PPN_Permits/Persetujuan_Lingkungan/C JBB/A2. DPPU SHAFTHI/A2 DPPU SHAFTI Persetujuan Lingkungan (SK.11).pdf has 76 pages.
# File data/folder/PPN_Permits/Persetujuan_Lingkungan/C JBB/C2. FT Bandung Group/Bandung Group - Padalarang/2012_UKL-UPL Padalarang (Rev 1).pdf has 259 pages.
# File data/folder/PPN_Permits/Persetujuan_Lingkungan/C JBB/C2. FT Bandung Group/Bandung Group - Padalarang/2011_Dokumen DPLH (UKL - UPL) SPBE Patra Trading Padalarang.pdf has 126 pages.
# File data/folder/PPN_Permits/Persetujuan_Lingkungan/C JBB/C2. FT Bandung Group/Bandung Group - Padalarang/2018_UKL-UPL Padalarang.pdf has 83 pages.
# File data/folder/PPN_Permits/Persetujuan_Lingkungan/C JBB/C2. FT Bandung Group/Bandung Group - Padalarang/2012_UKL-UPL Padalarang (Rev 2).pdf has 224 pages.
# File data/folder/PPN_Permits/Persetujuan_Lingkungan/C JBB/C2. FT Bandung Group/Bandung Group - Padalarang/2008_UKL-UPL Bandung Group Padalarang.pdf has 293 pages.
# File data/folder/PPN_Permits/Persetujuan_Lingkungan/A SBU/D2 IT Dumai/2022_IT Dumai Persetujuan Lingkungan (SK.224).pdf has 20 pages.
# File data/folder/PPN_Permits/Persetujuan_Lingkungan/A SBU/A1 FT Krueng Raya/2006_ UKL UPL Depot Krueng Raya.pdf has 141 pages.
# File data/folder/PPN_Permits/Persetujuan_Lingkungan/A SBU/A1 FT Krueng Raya/2014_Dokumen UKL- UPL TBBM Krueng Raya 2014.pdf has 170 pages.
# File data/folder/PPN_Permits/Persetujuan_Lingkungan/A SBU/A1 FT Krueng Raya/2004_Dokumen UKL UPL 2004 Krueng Raya.pdf has 145 pages.
# File data/folder/PPN_Permits/Persetujuan_Lingkungan/A SBU/A1 FT Krueng Raya/2020_Dokumen UKL - UPL TERMINAL BBM KRUENG RAYA 2020.pdf has 192 pages.
# File data/folder/PPN_Permits/Persetujuan_Lingkungan/A SBU/A1 FT Krueng Raya/2020_UKL _ UPL TERMINAL BBM KRUENG RAYA.pdf has 192 pages.
# File data/folder/PPN_Permits/Persetujuan_Lingkungan/A SBU/A1 FT Krueng Raya/2006_Dokumen UKL- UPL Depot Krueng Raya 2006.pdf has 141 pages.
# File data/folder/PPN_Permits/Persetujuan_Lingkungan/A SBU/A1 FT Krueng Raya/2021_UKL-UPL Pertamina Fuel Terminal Krueng Raya.pdf has 238 pages.
# File data/folder/PPN_Permits/Persetujuan_Lingkungan/A SBU/A1 FT Krueng Raya/2022_Persetujuan Lingkungan FT Krueng Raya (SK.5875).pdf has 39 pages.
# File data/folder/PPN_Permits/Persetujuan_Lingkungan/A SBU/A1 FT Krueng Raya/2014_UKL UPL TBBM Krueng Raya.pdf has 170 pages.
# File data/folder/PPN_Permits/Persetujuan_Lingkungan/A SBU/A1 FT Krueng Raya/2004_Dokumen UKL UPL Krueng Raya.pdf has 145 pages.
# File data/folder/PPN_Permits/Persetujuan_Lingkungan/A SBU/A1 FT Krueng Raya/2021_UKL-UPL Pertamina Fuel Terminal Krueng Raya 2021.pdf has 238 pages.
# File data/folder/PPN_Permits/Persetujuan_Lingkungan/B SBS/D2 DPPU Fatmawati/2022_DPPU Fatmawati Persetujuan Lingkungan (SK.5929).pdf has 37 pages.
# File data/folder/PPN_Permits/Persetujuan_Lingkungan/B SBS/B1 IT Palembang/IT Palembang Kertapati/2019_UKL-UPL TBBM Kertapati 2019.pdf has 172 pages.
# File data/folder/PPN_Permits/Persetujuan_Lingkungan/B SBS/B1 IT Palembang/IT Palembang Kertapati/1996_UKL-UPL TBBM Kertapati.pdf has 171 pages.
# File data/folder/PPN_Permits/Persetujuan_Lingkungan/B SBS/B1 IT Palembang/IT Palembang Kertapati/2011_UKL-UPL TBBM Kertapati.pdf has 202 pages.
# File data/folder/PPN_Permits/Persetujuan_Lingkungan/E JBN/D3 FT ENDE/2022_FT Ende Persetujuan Lingkungan (SK.1119).pdf has 37 pages.
# File data/folder/PPN_Permits/Persetujuan_Lingkungan/E JBN/B2 FT SANGGARAN/2016_UPL-UKL TBBM Sanggaran.pdf has 49 pages.
# File data/folder/PPN_Permits/Persetujuan_Lingkungan/E JBN/B2 FT SANGGARAN/2022_UKL UPL Depot Sanggaran.pdf has 137 pages.
# File data/folder/PPN_Permits/Persetujuan_Lingkungan/E JBN/B2 FT SANGGARAN/2018_UKL UPL TBBM Sanggaran.pdf has 220 pages.
# File data/folder/PPN_Permits/Persetujuan_Lingkungan/E JBN/B2 FT SANGGARAN/2013_UKL UPL Kegiatan Pengerukan Dermaga TBBM Sanggaran.pdf has 310 pages.
# File data/folder/PPN_Permits/Persetujuan_Lingkungan/D JBT/A1 IT SEMARANG/2022_IT Semarang Persetujuan Lingkungan (SK.686).pdf has 113 pages.
# File data/folder/PPN_Permits/Persetujuan_Lingkungan/F KAL/D1 IT Balikpapan/IT Balikpapan - Fuel Terminal/2021_IT Balikpapan - Fuel Persetujuan Lingkungan (SK.957).pdf has 23 pages.
# File data/folder/PPN_Permits/KKPR/MOR 7/RKKPR Stranas Jalur Pipa Hasanuddin - Makassar.pdf has 20 pages.
# File data/folder/PPN_Permits/KKPR/KKPR Stranas/16. RKKPR Stranas Jalur Pipa CB 1, CB 2, dan CB 3.pdf has 11 pages.
# File data/folder/PPN_Permits/KKPR/KKPR Stranas/14. RKKPR Stranas Jalur Pipa CB 2 (diluar tampalan jalur pipa CB 1, 2, dan 3).pdf has 16 pages.
# File data/folder/PPN_Permits/KKPR/KKPR Stranas/18. RKKPR Stranas Jalur Pipa Hasanuddin - Makassar.pdf has 20 pages.
# Files with more than 10 pages: 108

# %%
short_files = []

for file_path, num_pages in zip(file_list, file_pages):
    if num_pages <= 10:
        short_files.append(file_path)

print(f"Files with 10 or fewer pages: {len(short_files)}")
# Out:
# Files with 10 or fewer pages: 63

# %%
tasks = [process_permit_metadata_async(file_path) for file_path in short_files[:20]]
metadata_result_test = await asyncio.gather(*tasks)
# Out:
# INFO:root:Processing file: data/folder/KPI_Permits/Sertifikat_PLO_SKPI/PLO RU VI/PIPELINE CRUDE OIL 24IN FROM SPM 150.000 DWT_1.pdf with 2 pages.
# INFO:root:Processing file: data/folder/KPI_Permits/Sertifikat_PLO_SKPI/PLO RU VI/PIPELINE NAPTHA 16X20IN FROM SPM 35.000 DWT.pdf with 2 pages.
# INFO:root:Processing file: data/folder/KPI_Permits/Sertifikat_PLO_SKPI/PLO RU VI/PIPELINE HOMC 16IN FROM SPM 17.500 DWT_1.pdf with 2 pages.
# INFO:root:Processing file: data/folder/KPI_Permits/Sertifikat_PLO_SKPI/PLO RU VI/PIPELINE CRUDE OIL 36IN FROM SPM 150.000 DWT_1.pdf with 2 pages.
# INFO:root:Processing file: data/folder/KPI_Permits/Sertifikat_PLO_SKPI/PLO RU VI/PIPELINE FLUSHING OIL 14IN FROM SPM 17.500 DWT_1.pdf with 2 pages.
# INFO:root:Processing file: data/folder/KPI_Permits/Sertifikat_PLO_SKPI/PLO RU V/1378_SKPI_SKPI OM DAN LAWE2 Feb 2018-Jan 2023.pdf with 1 pages.
# INFO:root:Processing file: data/folder/KPI_Permits/Sertifikat_PLO_SKPI/PLO RU II/PLO UTL KILANG SEI PAKNING.pdf with 5 pages.
# INFO:root:Processing file: data/folder/KPI_Permits/Sertifikat_PLO_SKPI/PLO RU II/PLO ITY KILANG SEI PAKNING.pdf with 6 pages.
# INFO:root:Processing file: data/folder/KPI_Permits/Sertifikat_PLO_SKPI/PLO RU VI/PLO FLUSHING SYSTEM.pdf with 4 pages.
# INFO:root:Processing file: data/folder/KPI_Permits/Sertifikat_PLO_SKPI/PLO RU V/1376_SKPI_SKPI HSC Feb 2018-Jan 2023.pdf with 1 pages.
# INFO:root:Processing file: data/folder/KPI_Permits/Sertifikat_PLO_SKPI/PLO RU VI/PLO SPL-SPM 165000 DWT.pdf with 4 pages.
# INFO:root:Processing file: data/folder/KPI_Permits/Sertifikat_PLO_SKPI/PLO RU II/PLO CDU KILANG SEI PAKNING.pdf with 6 pages.
# INFO:root:Processing file: data/folder/KPI_Permits/Sertifikat_PLO_SKPI/PLO RU IV/10 - Nomor 533_48-4_PLO_DMT_2021 PLO Instalasi Pipa Penyalur dari Area 60 ke Area 70.pdf with 3 pages.
# INFO:root:Processing file: data/folder/KPI_Permits/Sertifikat_PLO_SKPI/PLO RU V/1375_SKPI_SKPI HCC Feb 2018-Jan 2023.pdf with 1 pages.
# INFO:root:Processing file: data/folder/KPI_Permits/Sertifikat_PLO_SKPI/PLO RU V/0_SKPI_PLO New Balikpapan II Gas Flare.pdf with 4 pages.
# INFO:root:Processing file: data/folder/KPI_Permits/Sertifikat_PLO_SKPI/PLO RU IV/3 - Nomor 79_48-4_PLO_DMT_2022 PLO Instalasi Pipa Penyalur dari CIB 1 dan CIB 2 ke Area 70.pdf with 4 pages.
# INFO:root:Processing file: data/folder/KPI_Permits/Sertifikat_PLO_SKPI/PLO RU V/0_SKPI_PLO North Acid Gas Flare 2021-2024.pdf with 3 pages.
# INFO:root:Processing file: data/folder/KPI_Permits/Sertifikat_PLO_SKPI/PLO RU VI/PLO KLBB.pdf with 8 pages.
# INFO:root:Processing file: data/folder/KPI_Permits/Sertifikat_PLO_SKPI/PLO RU VI/_PLO EXOR.pdf with 6 pages.
# INFO:root:Processing file: data/folder/KPI_Permits/Sertifikat_PLO_SKPI/PLO RU V/1382_SKPI_PLO PIPA PENYALUR ø20in Jalur Terminal Lawe-Lawe ke Station Penajam (Onsore).pdf with 5 pages.

# %%
metadata_result = []

for file_path in short_files:
    metadata = process_permit_metadata(file_path)
    metadata_result.append(metadata)
# Out:
# INFO:root:Processing file: data/folder/KPI_Permits/Sertifikat_PLO_SKPI/PLO RU II/PLO CDU KILANG SEI PAKNING.pdf with 6 pages.
# INFO:httpx:HTTP Request: POST https://openai-permit.openai.azure.com/openai/deployments/gpt-4o/chat/completions?api-version=2024-02-01 "HTTP/1.1 200 OK"
# INFO:root:Processing file: data/folder/KPI_Permits/Sertifikat_PLO_SKPI/PLO RU II/PLO ITY KILANG SEI PAKNING.pdf with 6 pages.
# INFO:httpx:HTTP Request: POST https://openai-permit.openai.azure.com/openai/deployments/gpt-4o/chat/completions?api-version=2024-02-01 "HTTP/1.1 200 OK"
# INFO:root:Processing file: data/folder/KPI_Permits/Sertifikat_PLO_SKPI/PLO RU II/PLO UTL KILANG SEI PAKNING.pdf with 5 pages.
# INFO:httpx:HTTP Request: POST https://openai-permit.openai.azure.com/openai/deployments/gpt-4o/chat/completions?api-version=2024-02-01 "HTTP/1.1 200 OK"
# INFO:root:Processing file: data/folder/KPI_Permits/Sertifikat_PLO_SKPI/PLO RU VI/PLO SPL-SPM 165000 DWT.pdf with 4 pages.
# INFO:httpx:HTTP Request: POST https://openai-permit.openai.azure.com/openai/deployments/gpt-4o/chat/completions?api-version=2024-02-01 "HTTP/1.1 200 OK"
# INFO:root:Processing file: data/folder/KPI_Permits/Sertifikat_PLO_SKPI/PLO RU VI/PIPELINE CRUDE OIL 36IN FROM SPM 150.000 DWT_1.pdf with 2 pages.
# INFO:httpx:HTTP Request: POST https://openai-permit.openai.azure.com/openai/deployments/gpt-4o/chat/completions?api-version=2024-02-01 "HTTP/1.1 200 OK"
# INFO:root:Processing file: data/folder/KPI_Permits/Sertifikat_PLO_SKPI/PLO RU VI/_PLO EXOR.pdf with 6 pages.
# INFO:httpx:HTTP Request: POST https://openai-permit.openai.azure.com/openai/deployments/gpt-4o/chat/completions?api-version=2024-02-01 "HTTP/1.1 200 OK"
# INFO:root:Processing file: data/folder/KPI_Permits/Sertifikat_PLO_SKPI/PLO RU VI/PIPELINE NAPTHA 16X20IN FROM SPM 35.000 DWT.pdf with 2 pages.
# INFO:httpx:HTTP Request: POST https://openai-permit.openai.azure.com/openai/deployments/gpt-4o/chat/completions?api-version=2024-02-01 "HTTP/1.1 200 OK"
# INFO:root:Processing file: data/folder/KPI_Permits/Sertifikat_PLO_SKPI/PLO RU VI/PIPELINE HOMC 16IN FROM SPM 17.500 DWT_1.pdf with 2 pages.
# INFO:httpx:HTTP Request: POST https://openai-permit.openai.azure.com/openai/deployments/gpt-4o/chat/completions?api-version=2024-02-01 "HTTP/1.1 200 OK"
# INFO:root:Processing file: data/folder/KPI_Permits/Sertifikat_PLO_SKPI/PLO RU VI/PLO FLUSHING SYSTEM.pdf with 4 pages.
# INFO:httpx:HTTP Request: POST https://openai-permit.openai.azure.com/openai/deployments/gpt-4o/chat/completions?api-version=2024-02-01 "HTTP/1.1 200 OK"
# INFO:root:Processing file: data/folder/KPI_Permits/Sertifikat_PLO_SKPI/PLO RU VI/PIPELINE CRUDE OIL 24IN FROM SPM 150.000 DWT_1.pdf with 2 pages.
# INFO:httpx:HTTP Request: POST https://openai-permit.openai.azure.com/openai/deployments/gpt-4o/chat/completions?api-version=2024-02-01 "HTTP/1.1 200 OK"
# INFO:root:Processing file: data/folder/KPI_Permits/Sertifikat_PLO_SKPI/PLO RU VI/PLO KLBB.pdf with 8 pages.
# INFO:httpx:HTTP Request: POST https://openai-permit.openai.azure.com/openai/deployments/gpt-4o/chat/completions?api-version=2024-02-01 "HTTP/1.1 200 OK"
# INFO:root:Processing file: data/folder/KPI_Permits/Sertifikat_PLO_SKPI/PLO RU VI/PIPELINE FLUSHING OIL 14IN FROM SPM 17.500 DWT_1.pdf with 2 pages.
# INFO:httpx:HTTP Request: POST https://openai-permit.openai.azure.com/openai/deployments/gpt-4o/chat/completions?api-version=2024-02-01 "HTTP/1.1 200 OK"
# INFO:root:Processing file: data/folder/KPI_Permits/Sertifikat_PLO_SKPI/PLO RU IV/3 - Nomor 79_48-4_PLO_DMT_2022 PLO Instalasi Pipa Penyalur dari CIB 1 dan CIB 2 ke Area 70.pdf with 4 pages.
# INFO:httpx:HTTP Request: POST https://openai-permit.openai.azure.com/openai/deployments/gpt-4o/chat/completions?api-version=2024-02-01 "HTTP/1.1 200 OK"
# INFO:root:Processing file: data/folder/KPI_Permits/Sertifikat_PLO_SKPI/PLO RU IV/10 - Nomor 533_48-4_PLO_DMT_2021 PLO Instalasi Pipa Penyalur dari Area 60 ke Area 70.pdf with 3 pages.
# INFO:httpx:HTTP Request: POST https://openai-permit.openai.azure.com/openai/deployments/gpt-4o/chat/completions?api-version=2024-02-01 "HTTP/1.1 200 OK"
# INFO:root:Processing file: data/folder/KPI_Permits/Sertifikat_PLO_SKPI/PLO RU V/1378_SKPI_SKPI OM DAN LAWE2 Feb 2018-Jan 2023.pdf with 1 pages.
# INFO:httpx:HTTP Request: POST https://openai-permit.openai.azure.com/openai/deployments/gpt-4o/chat/completions?api-version=2024-02-01 "HTTP/1.1 200 OK"
# INFO:root:Processing file: data/folder/KPI_Permits/Sertifikat_PLO_SKPI/PLO RU V/0_SKPI_PLO New Balikpapan II Gas Flare.pdf with 4 pages.
# INFO:httpx:HTTP Request: POST https://openai-permit.openai.azure.com/openai/deployments/gpt-4o/chat/completions?api-version=2024-02-01 "HTTP/1.1 200 OK"
# INFO:root:Processing file: data/folder/KPI_Permits/Sertifikat_PLO_SKPI/PLO RU V/1382_SKPI_PLO PIPA PENYALUR ø20in Jalur Terminal Lawe-Lawe ke Station Penajam (Onsore).pdf with 5 pages.
# INFO:httpx:HTTP Request: POST https://openai-permit.openai.azure.com/openai/deployments/gpt-4o/chat/completions?api-version=2024-02-01 "HTTP/1.1 200 OK"
# INFO:root:Processing file: data/folder/KPI_Permits/Sertifikat_PLO_SKPI/PLO RU V/1376_SKPI_SKPI HSC Feb 2018-Jan 2023.pdf with 1 pages.
# INFO:httpx:HTTP Request: POST https://openai-permit.openai.azure.com/openai/deployments/gpt-4o/chat/completions?api-version=2024-02-01 "HTTP/1.1 200 OK"
# INFO:root:Processing file: data/folder/KPI_Permits/Sertifikat_PLO_SKPI/PLO RU V/0_SKPI_PLO North Acid Gas Flare 2021-2024.pdf with 3 pages.
# INFO:httpx:HTTP Request: POST https://openai-permit.openai.azure.com/openai/deployments/gpt-4o/chat/completions?api-version=2024-02-01 "HTTP/1.1 200 OK"
# INFO:root:Processing file: data/folder/KPI_Permits/Sertifikat_PLO_SKPI/PLO RU V/1375_SKPI_SKPI HCC Feb 2018-Jan 2023.pdf with 1 pages.
# INFO:httpx:HTTP Request: POST https://openai-permit.openai.azure.com/openai/deployments/gpt-4o/chat/completions?api-version=2024-02-01 "HTTP/1.1 200 OK"
# INFO:root:Processing file: data/folder/KPI_Permits/Sertifikat_PLO_SKPI/PLO RU VII/AREA/CDU.pdf with 5 pages.
# INFO:httpx:HTTP Request: POST https://openai-permit.openai.azure.com/openai/deployments/gpt-4o/chat/completions?api-version=2024-02-01 "HTTP/1.1 200 OK"
# INFO:root:Processing file: data/folder/KPI_Permits/Sertifikat_PLO_SKPI/PLO RU III/PLO RU III Alkilasi Unit Plaju Sumsel.pdf with 9 pages.
# INFO:httpx:HTTP Request: POST https://openai-permit.openai.azure.com/openai/deployments/gpt-4o/chat/completions?api-version=2024-02-01 "HTTP/1.1 200 OK"
# INFO:root:Processing file: data/folder/KPI_Permits/Sertifikat_PLO_SKPI/PLO RU III/PLO RU III CDU II Plaju Sumsel.pdf with 7 pages.
# INFO:httpx:HTTP Request: POST https://openai-permit.openai.azure.com/openai/deployments/gpt-4o/chat/completions?api-version=2024-02-01 "HTTP/1.1 200 OK"
# INFO:root:Processing file: data/folder/KPI_Permits/Sertifikat_PLO_SKPI/PLO RU III/PLO RU III CDU IV Plaju Sumsel.pdf with 8 pages.
# INFO:httpx:HTTP Request: POST https://openai-permit.openai.azure.com/openai/deployments/gpt-4o/chat/completions?api-version=2024-02-01 "HTTP/1.1 200 OK"
# INFO:root:Processing file: data/folder/KPI_Permits/Sertifikat_PLO_SKPI/PLO RU III/PLO RU III CDU VI Plaju Sumsel.pdf with 8 pages.
# INFO:httpx:HTTP Request: POST https://openai-permit.openai.azure.com/openai/deployments/gpt-4o/chat/completions?api-version=2024-02-01 "HTTP/1.1 200 OK"
# INFO:root:Processing file: data/folder/KPI_Permits/Sertifikat_PLO_SKPI/PLO RU III/PLO RU III StabilizerCAB Plaju Sumsel.pdf with 7 pages.
# INFO:httpx:HTTP Request: POST https://openai-permit.openai.azure.com/openai/deployments/gpt-4o/chat/completions?api-version=2024-02-01 "HTTP/1.1 200 OK"
# INFO:root:Processing file: data/folder/KPI_Permits/Sertifikat_PLO_SKPI/PLO RU III/PLO RU III PPU Plaju Sumsel.pdf with 7 pages.
# INFO:httpx:HTTP Request: POST https://openai-permit.openai.azure.com/openai/deployments/gpt-4o/chat/completions?api-version=2024-02-01 "HTTP/1.1 200 OK"
# INFO:root:Processing file: data/folder/KPI_Permits/Sertifikat_PLO_SKPI/PLO RU III/PLO RU III CDU V Plaju Sumsel.pdf with 8 pages.
# INFO:httpx:HTTP Request: POST https://openai-permit.openai.azure.com/openai/deployments/gpt-4o/chat/completions?api-version=2024-02-01 "HTTP/1.1 200 OK"
# INFO:root:Processing file: data/folder/KPI_Permits/Sertifikat_PLO_SKPI/PLO RU III/PLO RU III CDU III Plaju Sumsel.pdf with 7 pages.
# INFO:httpx:HTTP Request: POST https://openai-permit.openai.azure.com/openai/deployments/gpt-4o/chat/completions?api-version=2024-02-01 "HTTP/1.1 200 OK"
# INFO:root:Processing file: data/folder/KPI_Permits/Sertifikat_PLO_SKPI/PLO RU III/PLO RU III RFCCU Plaju Sumsel.pdf with 8 pages.
# INFO:httpx:HTTP Request: POST https://openai-permit.openai.azure.com/openai/deployments/gpt-4o/chat/completions?api-version=2024-02-01 "HTTP/1.1 200 OK"
# INFO:root:Processing file: data/folder/KPI_Permits/Sertifikat_PLO_SKPI/PLO RU III/PLO RU III HVU II Plaju Sumsel.pdf with 7 pages.
# INFO:httpx:HTTP Request: POST https://openai-permit.openai.azure.com/openai/deployments/gpt-4o/chat/completions?api-version=2024-02-01 "HTTP/1.1 200 OK"
# INFO:root:Processing file: data/folder/KPI_Permits/KKPR_KKPRL/RU III Plaju/KKPR Kilang RU III Area Banyuasi 1.pdf with 5 pages.
# INFO:httpx:HTTP Request: POST https://openai-permit.openai.azure.com/openai/deployments/gpt-4o/chat/completions?api-version=2024-02-01 "HTTP/1.1 200 OK"
# INFO:root:Processing file: data/folder/KPI_Permits/KKPR_KKPRL/RU III Plaju/KKPR Industri Kimia (KBLI 20117) Area Plaju.pdf with 3 pages.
# INFO:httpx:HTTP Request: POST https://openai-permit.openai.azure.com/openai/deployments/gpt-4o/chat/completions?api-version=2024-02-01 "HTTP/1.1 200 OK"
# INFO:root:Processing file: data/folder/KPI_Permits/KKPR_KKPRL/RU III Plaju/KKPR Kilang RU III Area Plaju.pdf with 3 pages.
# INFO:httpx:HTTP Request: POST https://openai-permit.openai.azure.com/openai/deployments/gpt-4o/chat/completions?api-version=2024-02-01 "HTTP/1.1 200 OK"
# INFO:root:Processing file: data/folder/KPI_Permits/KKPR_KKPRL/RU III Plaju/KKPR Industri Kimia (KBLI 20117) Area Banyuasi 1.pdf with 4 pages.
# INFO:httpx:HTTP Request: POST https://openai-permit.openai.azure.com/openai/deployments/gpt-4o/chat/completions?api-version=2024-02-01 "HTTP/1.1 200 OK"
# INFO:root:Processing file: data/folder/KPI_Permits/KKPR_KKPRL/RU III Plaju/KKPR Perumahan RU III Area Banyuasi 1.pdf with 7 pages.
# INFO:httpx:HTTP Request: POST https://openai-permit.openai.azure.com/openai/deployments/gpt-4o/chat/completions?api-version=2024-02-01 "HTTP/1.1 200 OK"
# INFO:root:Processing file: data/folder/KPI_Permits/KKPR_KKPRL/RU III Plaju/KKPR Perumahan RU III Area Plaju.pdf with 8 pages.
# INFO:httpx:HTTP Request: POST https://openai-permit.openai.azure.com/openai/deployments/gpt-4o/chat/completions?api-version=2024-02-01 "HTTP/1.1 200 OK"
# INFO:root:Processing file: data/folder/KPI_Permits/KKPR_KKPRL/RU II Dumai & Sei Pakning/KKPR Kilang RU II Sei Pakning.pdf with 3 pages.
# INFO:httpx:HTTP Request: POST https://openai-permit.openai.azure.com/openai/deployments/gpt-4o/chat/completions?api-version=2024-02-01 "HTTP/1.1 200 OK"
# INFO:root:Processing file: data/folder/KPI_Permits/KKPR_KKPRL/RU II Dumai & Sei Pakning/KKPRL RU II Sei Pakning SPL Naphta New.pdf with 4 pages.
# INFO:httpx:HTTP Request: POST https://openai-permit.openai.azure.com/openai/deployments/gpt-4o/chat/completions?api-version=2024-02-01 "HTTP/1.1 200 OK"
# INFO:root:Processing file: data/folder/KPI_Permits/KKPR_KKPRL/RU II Dumai & Sei Pakning/KKPR Kilang RU II Dumai.pdf with 4 pages.
# INFO:httpx:HTTP Request: POST https://openai-permit.openai.azure.com/openai/deployments/gpt-4o/chat/completions?api-version=2024-02-01 "HTTP/1.1 200 OK"
# INFO:root:Processing file: data/folder/KPI_Permits/KKPR_KKPRL/RU II Dumai & Sei Pakning/KKPRL RU II Sei Pakning SPL Kerosene New.pdf with 4 pages.
# INFO:httpx:HTTP Request: POST https://openai-permit.openai.azure.com/openai/deployments/gpt-4o/chat/completions?api-version=2024-02-01 "HTTP/1.1 200 OK"
# INFO:root:Processing file: data/folder/KPI_Permits/KKPR_KKPRL/RU II Dumai & Sei Pakning/KKPRL RU II Sei Pakning SPL Naphta Eksisting.pdf with 4 pages.
# INFO:httpx:HTTP Request: POST https://openai-permit.openai.azure.com/openai/deployments/gpt-4o/chat/completions?api-version=2024-02-01 "HTTP/1.1 200 OK"
# INFO:root:Processing file: data/folder/KPI_Permits/KKPR_KKPRL/RU II Dumai & Sei Pakning/KKPRL RU II Sei Pakning SPL Crude Oil Eksisting.pdf with 4 pages.
# INFO:httpx:HTTP Request: POST https://openai-permit.openai.azure.com/openai/deployments/gpt-4o/chat/completions?api-version=2024-02-01 "HTTP/1.1 200 OK"
# INFO:root:Processing file: data/folder/KPI_Permits/KKPR_KKPRL/RU II Dumai & Sei Pakning/KKPRL RU II Sei Pakning SPL ADO Eksisting.pdf with 4 pages.
# INFO:httpx:HTTP Request: POST https://openai-permit.openai.azure.com/openai/deployments/gpt-4o/chat/completions?api-version=2024-02-01 "HTTP/1.1 200 OK"
# INFO:root:Processing file: data/folder/KPI_Permits/KKPR_KKPRL/RU II Dumai & Sei Pakning/KKPRL RU II Sei Pakning Area Jetty.pdf with 4 pages.
# INFO:httpx:HTTP Request: POST https://openai-permit.openai.azure.com/openai/deployments/gpt-4o/chat/completions?api-version=2024-02-01 "HTTP/1.1 200 OK"
# INFO:root:Processing file: data/folder/KPI_Permits/KKPR_KKPRL/RU II Dumai & Sei Pakning/KKPRL - DHT RU II Dumai.pdf with 5 pages.
# INFO:httpx:HTTP Request: POST https://openai-permit.openai.azure.com/openai/deployments/gpt-4o/chat/completions?api-version=2024-02-01 "HTTP/1.1 200 OK"
# INFO:root:Processing file: data/folder/KPI_Permits/KKPR_KKPRL/RU II Dumai & Sei Pakning/KKPRL RU II Sei Pakning SPL Kerosene Eksisting.pdf with 4 pages.
# INFO:httpx:HTTP Request: POST https://openai-permit.openai.azure.com/openai/deployments/gpt-4o/chat/completions?api-version=2024-02-01 "HTTP/1.1 200 OK"
# INFO:root:Processing file: data/folder/KPI_Permits/KKPR_KKPRL/RU II Dumai & Sei Pakning/KKPRL RU II Sei Pakning SPL ADO New.pdf with 4 pages.
# INFO:httpx:HTTP Request: POST https://openai-permit.openai.azure.com/openai/deployments/gpt-4o/chat/completions?api-version=2024-02-01 "HTTP/1.1 200 OK"
# INFO:root:Processing file: data/folder/KPI_Permits/KKPR_KKPRL/RU II Dumai & Sei Pakning/KKPRL RU II Sei Pakning SPL Crude Oil New.pdf with 5 pages.
# INFO:httpx:HTTP Request: POST https://openai-permit.openai.azure.com/openai/deployments/gpt-4o/chat/completions?api-version=2024-02-01 "HTTP/1.1 200 OK"
# INFO:root:Processing file: data/folder/KPI_Permits/KKPR_KKPRL/RU VI Balongan/KKPR Perumahan RU VI Balongan.pdf with 2 pages.
# INFO:httpx:HTTP Request: POST https://openai-permit.openai.azure.com/openai/deployments/gpt-4o/chat/completions?api-version=2024-02-01 "HTTP/1.1 200 OK"
# INFO:root:Processing file: data/folder/KPI_Permits/KKPR_KKPRL/RU VI Balongan/KKPRL RU VI Balongan SPL No. 11 to SPM 17.500 DWT.pdf with 4 pages.
# INFO:httpx:HTTP Request: POST https://openai-permit.openai.azure.com/openai/deployments/gpt-4o/chat/completions?api-version=2024-02-01 "HTTP/1.1 200 OK"
# INFO:root:Processing file: data/folder/KPI_Permits/KKPR_KKPRL/RU VI Balongan/KKPRL RU VI Balongan Jetty, SPM dan Area Pengerukan.pdf with 10 pages.
# INFO:httpx:HTTP Request: POST https://openai-permit.openai.azure.com/openai/deployments/gpt-4o/chat/completions?api-version=2024-02-01 "HTTP/1.1 200 OK"
# INFO:root:Processing file: data/folder/KPI_Permits/KKPR_KKPRL/RU VI Balongan/KKPR Kilang RU VI Balongan.pdf with 4 pages.
# INFO:httpx:HTTP Request: POST https://openai-permit.openai.azure.com/openai/deployments/gpt-4o/chat/completions?api-version=2024-02-01 "HTTP/1.1 200 OK"
# INFO:root:Processing file: data/folder/KPI_Permits/KKPR_KKPRL/RU VI Balongan/KKPRL RU VI Balongan SPL No. 4 to SPM 165.000 DWT.pdf with 4 pages.
# INFO:httpx:HTTP Request: POST https://openai-permit.openai.azure.com/openai/deployments/gpt-4o/chat/completions?api-version=2024-02-01 "HTTP/1.1 200 OK"
# INFO:root:Processing file: data/folder/KPI_Permits/KKPR_KKPRL/RU VI Balongan/KKPRL RU VI Balongan SPL No. 5 to SPM 165.000 DWT.pdf with 4 pages.
# INFO:httpx:HTTP Request: POST https://openai-permit.openai.azure.com/openai/deployments/gpt-4o/chat/completions?api-version=2024-02-01 "HTTP/1.1 200 OK"
# INFO:root:Processing file: data/folder/KPI_Permits/KKPR_KKPRL/RU VI Balongan/KKPRL RU VI Balongan - SPM & SPL 35.000 DWT dan Dumping Area.pdf with 7 pages.
# INFO:httpx:HTTP Request: POST https://openai-permit.openai.azure.com/openai/deployments/gpt-4o/chat/completions?api-version=2024-02-01 "HTTP/1.1 200 OK"
# INFO:root:Processing file: data/folder/KPI_Permits/KKPR_KKPRL/RU V Balikpapan/KKPRL Pengerukan Alur Pelayaran RU V Balikpapan.pdf with 4 pages.
# INFO:httpx:HTTP Request: POST https://openai-permit.openai.azure.com/openai/deployments/gpt-4o/chat/completions?api-version=2024-02-01 "HTTP/1.1 200 OK"
# INFO:root:Processing file: data/folder/KPI_Permits/KKPR_KKPRL/RU V Balikpapan/KKPR Kilang RU V Balikpapan.pdf with 8 pages.
# INFO:httpx:HTTP Request: POST https://openai-permit.openai.azure.com/openai/deployments/gpt-4o/chat/completions?api-version=2024-02-01 "HTTP/1.1 200 OK"
# INFO:root:Processing file: data/folder/KPI_Permits/KKPR_KKPRL/RU IV Cilacap/KKPR Kilang RU IV Cilacap KBLI 19211.pdf with 5 pages.
# INFO:httpx:HTTP Request: POST https://openai-permit.openai.azure.com/openai/deployments/gpt-4o/chat/completions?api-version=2024-02-01 "HTTP/1.1 200 OK"
# INFO:root:Processing file: data/folder/KPI_Permits/KKPR_KKPRL/RU IV Cilacap/KKPR RU IV Cilacap KBLI 20117.pdf with 8 pages.
# INFO:httpx:HTTP Request: POST https://openai-permit.openai.azure.com/openai/deployments/gpt-4o/chat/completions?api-version=2024-02-01 "HTTP/1.1 200 OK"
# INFO:root:Processing file: data/folder/KPI_Permits/KKPR_KKPRL/RU IV Cilacap/KKPR RU IV Cilacap KBLI 20115.pdf with 8 pages.
# INFO:httpx:HTTP Request: POST https://openai-permit.openai.azure.com/openai/deployments/gpt-4o/chat/completions?api-version=2024-02-01 "HTTP/1.1 200 OK"
# INFO:root:Processing file: data/folder/KPI_Permits/KKPR_KKPRL/RU IV Cilacap/KKPR 86901 - Griya Sehat RU IV Cilacap.pdf with 6 pages.
# INFO:openai._base_client:Retrying request to /chat/completions in 0.458156 seconds
# INFO:httpx:HTTP Request: POST https://openai-permit.openai.azure.com/openai/deployments/gpt-4o/chat/completions?api-version=2024-02-01 "HTTP/1.1 200 OK"
# INFO:root:Processing file: data/folder/KPI_Permits/KKPR_KKPRL/RU IV Cilacap/KKPR KBLI 86105 - Klinik RU IV Cilacap.pdf with 6 pages.
# INFO:httpx:HTTP Request: POST https://openai-permit.openai.azure.com/openai/deployments/gpt-4o/chat/completions?api-version=2024-02-01 "HTTP/1.1 200 OK"

# %%
metadata_result
# Out:
# [{'file_path': 'data/folder/KPI_Permits/Sertifikat_PLO_SKPI/PLO RU II/PLO CDU KILANG SEI PAKNING.pdf',
#   'issue_date': '2022-12-19',
#   'expiration_date': '2026-07-18',
#   'permit_type': 'PLO',
#   'summary': "This permit grants 'fit-for-operation' approval to PT Kilang Pertamina Internasional for their Crude Distillation Unit (CDU) at Bukit Batu, Bengkalis Riau. The approval follows technical inspections ensuring compliance with safety and operational standards. It specifies design and operational parameters, risk analysis, and inspection intervals. PT Kilang Pertamina Internasional bears full responsibility for environmental safety and adherence to conditions outlined in the permit. The document also highlights technical details and inspection protocols for the installation and equipment used.",
#   'usage': CompletionUsage(completion_tokens=133, prompt_tokens=5771, total_tokens=5904, completion_tokens_details=CompletionTokensDetails(accepted_prediction_tokens=None, audio_tokens=0, reasoning_tokens=0, rejected_prediction_tokens=None), prompt_tokens_details=PromptTokensDetails(audio_tokens=0, cached_tokens=5760))},
#  {'file_path': 'data/folder/KPI_Permits/Sertifikat_PLO_SKPI/PLO RU II/PLO ITY KILANG SEI PAKNING.pdf',
#   'issue_date': '2022-12-19',
#   'expiration_date': '2026-07-18',
#   'permit_type': 'PLO',
#   'summary': 'This permit, issued by the Directorate of Oil and Gas, approves operational feasibility for the Tank and Yard Installation (ITY) located in Bengkalis. It ensures compliance with technical and safety standards under national and environmental regulations. The installation caters to storage and distribution of crude oil and related products. Regular inspections are mandated every 6 months for fire protection, instrument systems, and other critical components. The permit outlines design parameters, operational conditions, and recommendations to mitigate risks like overfill and safety device issues, ensuring sustainable operations.',
#   'usage': CompletionUsage(completion_tokens=133, prompt_tokens=5771, total_tokens=5904, completion_tokens_details=CompletionTokensDetails(accepted_prediction_tokens=None, audio_tokens=0, reasoning_tokens=0, rejected_prediction_tokens=None), prompt_tokens_details=PromptTokensDetails(audio_tokens=0, cached_tokens=0))},
#  {'file_path': 'data/folder/KPI_Permits/Sertifikat_PLO_SKPI/PLO RU II/PLO UTL KILANG SEI PAKNING.pdf',
#   'issue_date': '2022-12-19',
#   'expiration_date': '2026-07-18',
#   'permit_type': 'PLO',
#   'summary': 'This permit approves the operation eligibility of PT Kilang Pertamina Internasional, detailing conditions for technical inspections and safety measures. The utility installation includes coordination data, capacities, and operational design specifics. Inspections must refer to stipulated standards and regular intervals, ensuring compliance with legal regulations. Equipment inspections include categorization, methods, and inspection ranges to maintain operational safety. The license is valid until mid-2026, requiring adherence to specified technical reports and safety protocols for sustaining operational integrity.',
#   'usage': CompletionUsage(completion_tokens=124, prompt_tokens=4863, total_tokens=4987, completion_tokens_details=CompletionTokensDetails(accepted_prediction_tokens=None, audio_tokens=0, reasoning_tokens=0, rejected_prediction_tokens=None), prompt_tokens_details=PromptTokensDetails(audio_tokens=0, cached_tokens=0))},
#  {'file_path': 'data/folder/KPI_Permits/Sertifikat_PLO_SKPI/PLO RU VI/PLO SPL-SPM 165000 DWT.pdf',
#   'issue_date': '2023-08-23',
#   'expiration_date': '2027-06-07',
#   'permit_type': 'PLO',
#   'summary': 'This permit authorizes the operation of SPL & SPM pipelines for crude oil handling by PT Kilang Pertamina International at the Refinery Unit VI Balongan, Indramayu, Java Barat. It adheres to the requirements of safety inspections, technical certifications, regional restrictions, and environmental regulations. The permit includes conditions for maintaining operational standards, regular safety inspections, and timely reporting of any installation modifications. It remains valid until June 2027 with mandatory annual reviews for continued compliance and operational safety.',
#   'usage': CompletionUsage(completion_tokens=128, prompt_tokens=2831, total_tokens=2959, completion_tokens_details=CompletionTokensDetails(accepted_prediction_tokens=None, audio_tokens=0, reasoning_tokens=0, rejected_prediction_tokens=None), prompt_tokens_details=PromptTokensDetails(audio_tokens=0, cached_tokens=0))},
#  {'file_path': 'data/folder/KPI_Permits/Sertifikat_PLO_SKPI/PLO RU VI/PIPELINE CRUDE OIL 36IN FROM SPM 150.000 DWT_1.pdf',
#   'issue_date': '2022-01-06',
#   'expiration_date': '2025-11-08',
#   'permit_type': 'PLO',
#   'summary': 'This permit, issued by the Directorate General of Oil and Gas, approves the operation of the crude oil pipe installation (NPS 36”) from SPM 150,000 DWT to Block Valve EOR I. It outlines safety, compliance, user responsibilities, and technical data including capacities and operational guidelines. The permit remains valid provided inspections and maintenance meet necessary standards, with safety as a priority. It mandates reporting any operational changes and contains specific obligations for oil installation users.',
#   'usage': CompletionUsage(completion_tokens=124, prompt_tokens=2139, total_tokens=2263, completion_tokens_details=CompletionTokensDetails(accepted_prediction_tokens=None, audio_tokens=0, reasoning_tokens=0, rejected_prediction_tokens=None), prompt_tokens_details=PromptTokensDetails(audio_tokens=0, cached_tokens=0))},
#  {'file_path': 'data/folder/KPI_Permits/Sertifikat_PLO_SKPI/PLO RU VI/_PLO EXOR.pdf',
#   'issue_date': '2022-03-08',
#   'expiration_date': '2025-01-19',
#   'permit_type': 'PLO',
#   'summary': 'This permit documents the approval for operational feasibility of EXOR facilities owned by PT Kilang Pertamina Internasional. It confirms compliance with safety standards, legislation, and technical requirements for operations involving crude oil and related products. Conditions include reporting changes to installations, maintaining valid inspection certifications, and conducting safety inspections before expiration. The permit is valid from the issued date to January 19, 2025, for activities such as refining and processing oil and gas in Indramayu, West Java. Key technical details and safety regulations are outlined for compliance.',
#   'usage': CompletionUsage(completion_tokens=137, prompt_tokens=5771, total_tokens=5908, completion_tokens_details=CompletionTokensDetails(accepted_prediction_tokens=None, audio_tokens=0, reasoning_tokens=0, rejected_prediction_tokens=None), prompt_tokens_details=PromptTokensDetails(audio_tokens=0, cached_tokens=0))},
#  {'file_path': 'data/folder/KPI_Permits/Sertifikat_PLO_SKPI/PLO RU VI/PIPELINE NAPTHA 16X20IN FROM SPM 35.000 DWT.pdf',
#   'issue_date': '2022-01-06',
#   'expiration_date': '2025-11-08',
#   'permit_type': 'PLO',
#   'summary': 'This permit authorizes the operation of a naphtha pipeline installation connecting SPM 35,000 DWT to Block Valve Exor I, with safety measures and maintenance requirements specified. It applies to PT Kilang Pertamina International RU VI Balongan and outlines key conditions such as safety inspections, reporting of changes to installations, and adherence to standards. The validity of the permit is contingent upon compliance with the safety certificate. It also discusses technical details, including pipeline dimensions and operational limits, and provides recommendations for corrosion prevention and emergency response improvements.',
#   'usage': CompletionUsage(completion_tokens=137, prompt_tokens=2139, total_tokens=2276, completion_tokens_details=CompletionTokensDetails(accepted_prediction_tokens=None, audio_tokens=0, reasoning_tokens=0, rejected_prediction_tokens=None), prompt_tokens_details=PromptTokensDetails(audio_tokens=0, cached_tokens=0))},
#  {'file_path': 'data/folder/KPI_Permits/Sertifikat_PLO_SKPI/PLO RU VI/PIPELINE HOMC 16IN FROM SPM 17.500 DWT_1.pdf',
#   'issue_date': '2022-01-06',
#   'expiration_date': '2025-11-08',
#   'permit_type': 'PLO',
#   'summary': 'This permit approves the operation of the Ballast Water Pipeline for SPM 17,500 DWT to Block Valve EXOR I in Java, Indonesia. Issued for PT Kilang Pertamina International RU VI Balongan, it specifies compliance with safety regulations and requires regular inspections and maintenance. Key conditions include environmental suitability certificates, adherence to ASME standards, and storage safety procedures. The pipeline is classified as hazardous and operational for over 20 years with technical specifications laid out for temperature, pressure, and dimension safety.',
#   'usage': CompletionUsage(completion_tokens=132, prompt_tokens=2139, total_tokens=2271, completion_tokens_details=CompletionTokensDetails(accepted_prediction_tokens=None, audio_tokens=0, reasoning_tokens=0, rejected_prediction_tokens=None), prompt_tokens_details=PromptTokensDetails(audio_tokens=0, cached_tokens=0))},
#  {'file_path': 'data/folder/KPI_Permits/Sertifikat_PLO_SKPI/PLO RU VI/PLO FLUSHING SYSTEM.pdf',
#   'issue_date': '2023-08-23',
#   'expiration_date': '2027-06-07',
#   'permit_type': 'PLO',
#   'summary': 'The permit approves the operational feasibility of the Flushing System Facilities for PT Kilang Pertamina Internasional at the Refinery Unit VI Balongan, Indramayu, Java Barat. It ensures compliance with environmental laws, technical inspection standards, and safety regulations. The permit specifies operating conditions including capacity, pressure, temperature, and fluid type. Regular inspections are mandated, with expiration within three years. Any changes or events affecting operational integrity require re-inspection or permit review.',
#   'usage': CompletionUsage(completion_tokens=122, prompt_tokens=2831, total_tokens=2953, completion_tokens_details=CompletionTokensDetails(accepted_prediction_tokens=None, audio_tokens=0, reasoning_tokens=0, rejected_prediction_tokens=None), prompt_tokens_details=PromptTokensDetails(audio_tokens=0, cached_tokens=0))},
#  {'file_path': 'data/folder/KPI_Permits/Sertifikat_PLO_SKPI/PLO RU VI/PIPELINE CRUDE OIL 24IN FROM SPM 150.000 DWT_1.pdf',
#   'issue_date': '2022-01-06',
#   'expiration_date': '2023-01-06',
#   'permit_type': 'PLO',
#   'summary': 'The permit approves the operation of the crude oil pipeline installation (NPS 24”) from SPM 150,000 DWT to Block Valve at Pertamina OGT Field. It outlines user and owner details, installation type, location, and technical data. Compliance with safety regulations and periodic inspections is required. The operational lifespan exceeds 20 years based on RLA (2021), and all operation/maintenance activities must ensure adherence to prescribed standards. Emergency procedures and monitoring practices for corrosion are stressed alongside regular ROW inspections and safety requirements.',
#   'usage': CompletionUsage(completion_tokens=136, prompt_tokens=2139, total_tokens=2275, completion_tokens_details=CompletionTokensDetails(accepted_prediction_tokens=None, audio_tokens=0, reasoning_tokens=0, rejected_prediction_tokens=None), prompt_tokens_details=PromptTokensDetails(audio_tokens=0, cached_tokens=0))},
#  {'file_path': 'data/folder/KPI_Permits/Sertifikat_PLO_SKPI/PLO RU VI/PLO KLBB.pdf',
#   'issue_date': '2023-08-23',
#   'expiration_date': '2027-06-07',
#   'permit_type': 'PLO',
#   'summary': "Approval for operating installations and equipment at PT Pertamina's Langit Biru Balongan refinery. Ensures compliance with regulations, safety standards, and technical requirements. Includes inspections and assessments, emphasizing personnel and environmental safety. Valid until 7 June 2027, with necessary re-inspection three years before expiration.",
#   'usage': CompletionUsage(completion_tokens=91, prompt_tokens=5339, total_tokens=5430, completion_tokens_details=CompletionTokensDetails(accepted_prediction_tokens=None, audio_tokens=0, reasoning_tokens=0, rejected_prediction_tokens=None), prompt_tokens_details=PromptTokensDetails(audio_tokens=0, cached_tokens=0))},
#  {'file_path': 'data/folder/KPI_Permits/Sertifikat_PLO_SKPI/PLO RU VI/PIPELINE FLUSHING OIL 14IN FROM SPM 17.500 DWT_1.pdf',
#   'issue_date': '2022-01-06',
#   'expiration_date': '2025-11-08',
#   'permit_type': 'PLO',
#   'summary': 'This permit represents the approval for operation regarding the Flushing Oil NPS 14-inch piping installation at the SPM 17,500 DWT KE Block Valve EXOR I location. PT Kilang Pertamina Internasional is responsible for maintaining safety regulations. All installation changes require inspection reporting. Compliance with technical standards, operational guidelines, and environmental factors is mandatory during the permit period. Validity applies as long as the inspection certifications are maintained, with re-inspections required before the permit expires.',
#   'usage': CompletionUsage(completion_tokens=127, prompt_tokens=2139, total_tokens=2266, completion_tokens_details=CompletionTokensDetails(accepted_prediction_tokens=None, audio_tokens=0, reasoning_tokens=0, rejected_prediction_tokens=None), prompt_tokens_details=PromptTokensDetails(audio_tokens=0, cached_tokens=0))},
#  {'file_path': 'data/folder/KPI_Permits/Sertifikat_PLO_SKPI/PLO RU IV/3 - Nomor 79_48-4_PLO_DMT_2022 PLO Instalasi Pipa Penyalur dari CIB 1 dan CIB 2 ke Area 70.pdf',
#   'issue_date': '2022-02-08',
#   'expiration_date': '2025-03-26',
#   'permit_type': 'PLO',
#   'summary': 'This permit confirms operational feasibility for the Cross Country Pipe Line (CCPL) at Crude Island Berth (CIB) of PT Pertamina Kilang International RU IV Cilacap. It ensures compliance with regulations and standards and requires periodic safety inspections. Any installation modifications must be reported. It is valid as long as supporting inspection certificates are effective, and permits are subject to review if deemed unsuitable for operations.',
#   'usage': CompletionUsage(completion_tokens=111, prompt_tokens=3955, total_tokens=4066, completion_tokens_details=CompletionTokensDetails(accepted_prediction_tokens=None, audio_tokens=0, reasoning_tokens=0, rejected_prediction_tokens=None), prompt_tokens_details=PromptTokensDetails(audio_tokens=0, cached_tokens=0))},
#  {'file_path': 'data/folder/KPI_Permits/Sertifikat_PLO_SKPI/PLO RU IV/10 - Nomor 533_48-4_PLO_DMT_2021 PLO Instalasi Pipa Penyalur dari Area 60 ke Area 70.pdf',
#   'issue_date': '2021-08-24',
#   'expiration_date': '2025-03-30',
#   'permit_type': 'PLO',
#   'summary': "This permit approves the operation feasibility of PT Pertamina's piping installation from Area 60 (Lomanis) to Terminal Area 70, Jawa Tengah. It outlines conditions including safety inspections, maintenance requirements, compliance with technical standards, and periodic checks before expiration. The maximum operation pressure is defined as 21.51 kg/cm² with specific technical data attached. It emphasizes the use of procedures like cathodic protection, intelligent pigging, routine monitoring, and frequent evaluations to ensure pipeline safety and efficiency throughout its lifespan.",
#   'usage': CompletionUsage(completion_tokens=133, prompt_tokens=3047, total_tokens=3180, completion_tokens_details=CompletionTokensDetails(accepted_prediction_tokens=None, audio_tokens=0, reasoning_tokens=0, rejected_prediction_tokens=None), prompt_tokens_details=PromptTokensDetails(audio_tokens=0, cached_tokens=0))},
#  {'file_path': 'data/folder/KPI_Permits/Sertifikat_PLO_SKPI/PLO RU V/1378_SKPI_SKPI OM DAN LAWE2 Feb 2018-Jan 2023.pdf',
#   'issue_date': '2018-02-23',
#   'expiration_date': '2023-01-05',
#   'permit_type': 'PLO',
#   'summary': 'The permit certifies PT Pertamina (Persero) RU V Balikpapan for operating installations handling Oil Movement Balikpapan and Lawe-Lawe. It is based on Indonesian regulations and ensures safety, health, and environmental management. Key requirements include reporting modifications, reinspection after installation changes, and operational responsibility by Pertamina. It is valid for five years from issuance and mandates technical evaluations before its expiration.',
#   'usage': CompletionUsage(completion_tokens=113, prompt_tokens=1231, total_tokens=1344, completion_tokens_details=CompletionTokensDetails(accepted_prediction_tokens=None, audio_tokens=0, reasoning_tokens=0, rejected_prediction_tokens=None), prompt_tokens_details=PromptTokensDetails(audio_tokens=0, cached_tokens=0))},
#  {'file_path': 'data/folder/KPI_Permits/Sertifikat_PLO_SKPI/PLO RU V/0_SKPI_PLO New Balikpapan II Gas Flare.pdf',
#   'issue_date': '2022-06-07',
#   'expiration_date': '2026-03-01',
#   'permit_type': 'PLO',
#   'summary': 'The permit approves the operation of the New Balikpapan II Gas Flare, certifying compliance with safety and technical standards. It outlines user information, key specifications, and design details. It emphasizes inspections, operational conditions, and procedural compliance. PT Kilang Pertamina Internasional RU V Balikpapan is responsible for safety adherence. Changes in installation or operation require reporting and inspections. The permit remains valid contingent on periodic safety evaluations and proper documentation.',
#   'usage': CompletionUsage(completion_tokens=120, prompt_tokens=3955, total_tokens=4075, completion_tokens_details=CompletionTokensDetails(accepted_prediction_tokens=None, audio_tokens=0, reasoning_tokens=0, rejected_prediction_tokens=None), prompt_tokens_details=PromptTokensDetails(audio_tokens=0, cached_tokens=0))},
#  {'file_path': 'data/folder/KPI_Permits/Sertifikat_PLO_SKPI/PLO RU V/1382_SKPI_PLO PIPA PENYALUR ø20in Jalur Terminal Lawe-Lawe ke Station Penajam (Onsore).pdf',
#   'issue_date': '2023-11-27',
#   'expiration_date': '2027-10-23',
#   'permit_type': 'PLO',
#   'summary': "The permit approves the operational fitness of the 'Pipa Penyalur Minyak Bumi 20' installation at Terminal Lawe Lawe - Penajam, owned by PT Kilang Pertamina Internasional. It complies with technical and safety standards for crude oil transportation. Users must implement system monitoring, conduct periodic inspections, and follow technical guidelines. Validity is subject to compliance, with provisions for review or renewal if operational conditions change.",
#   'usage': CompletionUsage(completion_tokens=117, prompt_tokens=4863, total_tokens=4980, completion_tokens_details=CompletionTokensDetails(accepted_prediction_tokens=None, audio_tokens=0, reasoning_tokens=0, rejected_prediction_tokens=None), prompt_tokens_details=PromptTokensDetails(audio_tokens=0, cached_tokens=0))},
#  {'file_path': 'data/folder/KPI_Permits/Sertifikat_PLO_SKPI/PLO RU V/1376_SKPI_SKPI HSC Feb 2018-Jan 2023.pdf',
#   'issue_date': '2018-02-23',
#   'expiration_date': '2023-01-05',
#   'permit_type': 'PLO',
#   'summary': 'This permit certifies the feasibility of usage of the HydroSkimming Complex (HSC) owned and operated by PT Pertamina (Persero) RU V Balikpapan. It verifies safety standards, environmental compliance, and modifications reporting requirements. Key operators include Bechtel Great Britain Limited. It permits operation for processing dual-phase productions of oil and gas with a capacity of 200 MBSD, requiring inspections before expiration. PT Pertamina is tasked with technical safety and obligatory reporting conditions to the Directorate General before modifications or continuing operations.',
#   'usage': CompletionUsage(completion_tokens=136, prompt_tokens=1231, total_tokens=1367, completion_tokens_details=CompletionTokensDetails(accepted_prediction_tokens=None, audio_tokens=0, reasoning_tokens=0, rejected_prediction_tokens=None), prompt_tokens_details=PromptTokensDetails(audio_tokens=0, cached_tokens=0))},
#  {'file_path': 'data/folder/KPI_Permits/Sertifikat_PLO_SKPI/PLO RU V/0_SKPI_PLO North Acid Gas Flare 2021-2024.pdf',
#   'issue_date': '2021-05-22',
#   'expiration_date': '2024-08-05',
#   'permit_type': 'PLO',
#   'summary': "The permit serves as approval for the operation of the North Acid Gas Flare installation owned by PT Pertamina (Persero) RU V Balikpapan. It specifies safety evaluations, required compliance with regulations, and technical standards for operation within the oil and gas sector. The permit includes the installation's description, conditions for use, safety inspection requirements, and ongoing reporting obligations for changes or incidents affecting operation suitability.",
#   'usage': CompletionUsage(completion_tokens=111, prompt_tokens=3047, total_tokens=3158, completion_tokens_details=CompletionTokensDetails(accepted_prediction_tokens=None, audio_tokens=0, reasoning_tokens=0, rejected_prediction_tokens=None), prompt_tokens_details=PromptTokensDetails(audio_tokens=0, cached_tokens=0))},
#  {'file_path': 'data/folder/KPI_Permits/Sertifikat_PLO_SKPI/PLO RU V/1375_SKPI_SKPI HCC Feb 2018-Jan 2023.pdf',
#   'issue_date': '2018-02-23',
#   'expiration_date': '2023-01-05',
#   'permit_type': 'KKPR/KKPRL',
#   'summary': 'The permit certifies the eligibility of the Hydrocracking Complex (HCC) installation at PT Pertamina RU V Balikpapan for safety, health, and environmental standards. It is issued under regulations like the Mining Act and directives by the Directorate. The installation has an 81 MBSD capacity and is used for dual-phase oil and gas processing. Compliance with modification reporting and periodic inspections is mandatory, with Pertamina RU V responsible for operational safety. Renewal and technical assessments are required three months before expiration.',
#   'usage': CompletionUsage(completion_tokens=135, prompt_tokens=1231, total_tokens=1366, completion_tokens_details=CompletionTokensDetails(accepted_prediction_tokens=None, audio_tokens=0, reasoning_tokens=0, rejected_prediction_tokens=None), prompt_tokens_details=PromptTokensDetails(audio_tokens=0, cached_tokens=0))},
#  {'file_path': 'data/folder/KPI_Permits/Sertifikat_PLO_SKPI/PLO RU VII/AREA/CDU.pdf',
#   'issue_date': '2022-12-27',
#   'expiration_date': '2024-11-02',
#   'permit_type': 'PLO',
#   'summary': 'This permit is issued to PT Kilang Pertamina Internasional RU VII Kasim for the operation of its Crude Distillation Unit (CDU). It confirms compliance with safety regulations and technical standards, with inspections conducted by certified agencies. The CDU has a capacity of 10,000 BOPD and processes crude oil into various products such as diesel, kerosene, and others. The permit mandates periodic inspections, adherence to safety protocols, and valid technical certifications to ensure continued operations.',
#   'usage': CompletionUsage(completion_tokens=127, prompt_tokens=3458, total_tokens=3585, completion_tokens_details=CompletionTokensDetails(accepted_prediction_tokens=None, audio_tokens=0, reasoning_tokens=0, rejected_prediction_tokens=None), prompt_tokens_details=PromptTokensDetails(audio_tokens=0, cached_tokens=0))},
#  {'file_path': 'data/folder/KPI_Permits/Sertifikat_PLO_SKPI/PLO RU III/PLO RU III Alkilasi Unit Plaju Sumsel.pdf',
#   'issue_date': '2023-02-09',
#   'expiration_date': '2026-01-21',
#   'permit_type': 'PLO',
#   'summary': 'The permit approves the operation of 10 units at PT Pertamina Kilang Internasional RU III Plaju for oil and gas activities. It ensures compliance with safety inspections, technical standards, and regulations. The installations must adhere to the specified design capacities, safety protocols, and inspection schedules. The approval is valid until 2026, with regular checks and operational documentation required for ongoing compliance.',
#   'usage': CompletionUsage(completion_tokens=106, prompt_tokens=8495, total_tokens=8601, completion_tokens_details=CompletionTokensDetails(accepted_prediction_tokens=None, audio_tokens=0, reasoning_tokens=0, rejected_prediction_tokens=None), prompt_tokens_details=PromptTokensDetails(audio_tokens=0, cached_tokens=0))},
#  {'file_path': 'data/folder/KPI_Permits/Sertifikat_PLO_SKPI/PLO RU III/PLO RU III CDU II Plaju Sumsel.pdf',
#   'issue_date': '2023-02-09',
#   'expiration_date': '2026-01-21',
#   'permit_type': 'PLO',
#   'summary': 'The permit grants operational approval for 10 units of crude distiller installations (CDU II) at PT Pertamina Kilang Internasional RU III Plaju, emphasizing compliance with safety and technical standards based on inspections and regulations. It mandates regular safety inspections, adherence to standards by Ministerial Regulations, and requires reporting for any modifications or issues affecting operational viability.',
#   'usage': CompletionUsage(completion_tokens=100, prompt_tokens=6679, total_tokens=6779, completion_tokens_details=CompletionTokensDetails(accepted_prediction_tokens=None, audio_tokens=0, reasoning_tokens=0, rejected_prediction_tokens=None), prompt_tokens_details=PromptTokensDetails(audio_tokens=0, cached_tokens=1152))},
#  {'file_path': 'data/folder/KPI_Permits/Sertifikat_PLO_SKPI/PLO RU III/PLO RU III CDU IV Plaju Sumsel.pdf',
#   'issue_date': '2023-02-09',
#   'expiration_date': '2026-01-21',
#   'permit_type': 'PLO',
#   'summary': 'The permit grants approval for the operation of 10 crude distiller units at PT Pertamina Kilang Internasional RU III Plaju. It is based on technical inspections, safety evaluations, and compliance with regulations. Pertamina is responsible for adherence to standards, safety measures, and inspections upon modifications or nearing expiration. The validity period is linked to the RLA and safety certifications. Regular maintenance and inspections are stipulated to ensure operational safety and efficiency.',
#   'usage': CompletionUsage(completion_tokens=117, prompt_tokens=7587, total_tokens=7704, completion_tokens_details=CompletionTokensDetails(accepted_prediction_tokens=None, audio_tokens=0, reasoning_tokens=0, rejected_prediction_tokens=None), prompt_tokens_details=PromptTokensDetails(audio_tokens=0, cached_tokens=0))},
#  {'file_path': 'data/folder/KPI_Permits/Sertifikat_PLO_SKPI/PLO RU III/PLO RU III CDU VI Plaju Sumsel.pdf',
#   'issue_date': '2023-02-09',
#   'expiration_date': '2026-01-21',
#   'permit_type': 'PLO',
#   'summary': 'The permit authorizes the operation of 10 units at the PT Pertamina Kilang Internasional RU III Plaju. It ensures compliance with technical inspections and safety checks under existing laws, standards, and practices. The scope includes crude oil processing installations with specific requirements for periodic safety inspections, certifications, and maintenance. Safety assessments, including RLA evaluations and technical checks, are mandated before expiration. The permit also highlights operator responsibility for safety, compliance, and reporting any changes in installations. Validity extends until certifications lapse and must follow guidelines from the Directorate General of Oil and Gas.',
#   'usage': CompletionUsage(completion_tokens=144, prompt_tokens=7587, total_tokens=7731, completion_tokens_details=CompletionTokensDetails(accepted_prediction_tokens=None, audio_tokens=0, reasoning_tokens=0, rejected_prediction_tokens=None), prompt_tokens_details=PromptTokensDetails(audio_tokens=0, cached_tokens=0))},
#  {'file_path': 'data/folder/KPI_Permits/Sertifikat_PLO_SKPI/PLO RU III/PLO RU III StabilizerCAB Plaju Sumsel.pdf',
#   'issue_date': '2023-02-09',
#   'expiration_date': '2026-01-21',
#   'permit_type': 'PLO',
#   'summary': 'This permit provides approval for the operation of 10 units of PT Pertamina Kilang Internasional RU III Plaju. It confirms compliance with safety and technical standards through inspections and assessments as per regulations. The permit outlines responsibilities for maintaining safety, conducting regular inspections, and ensuring compliance for continued operation in oil and gas business activities. Expiration is set for 21 January 2026 unless revoked for non-compliance or unsafe conditions.',
#   'usage': CompletionUsage(completion_tokens=115, prompt_tokens=6679, total_tokens=6794, completion_tokens_details=CompletionTokensDetails(accepted_prediction_tokens=None, audio_tokens=0, reasoning_tokens=0, rejected_prediction_tokens=None), prompt_tokens_details=PromptTokensDetails(audio_tokens=0, cached_tokens=1152))},
#  {'file_path': 'data/folder/KPI_Permits/Sertifikat_PLO_SKPI/PLO RU III/PLO RU III PPU Plaju Sumsel.pdf',
#   'issue_date': '2023-02-09',
#   'expiration_date': '2026-01-21',
#   'permit_type': 'PLO',
#   'summary': 'This permit grants PT Pertamina Kilang Internasional RU III Plaju approval for operational safety of 10 polypropylene processing units. Based on relevant regulations and technical inspections, the units comply with safety standards and can be operated subject to thorough inspections and adherence to technical norms. Periodic assessments are required to ensure compliance. The decision issued is effective until the provided expiration date and mandates related documents and certifications.',
#   'usage': CompletionUsage(completion_tokens=108, prompt_tokens=6679, total_tokens=6787, completion_tokens_details=CompletionTokensDetails(accepted_prediction_tokens=None, audio_tokens=0, reasoning_tokens=0, rejected_prediction_tokens=None), prompt_tokens_details=PromptTokensDetails(audio_tokens=0, cached_tokens=1152))},
#  {'file_path': 'data/folder/KPI_Permits/Sertifikat_PLO_SKPI/PLO RU III/PLO RU III CDU V Plaju Sumsel.pdf',
#   'issue_date': '2023-02-09',
#   'expiration_date': '2026-01-21',
#   'permit_type': 'PLO',
#   'summary': 'The permit is issued for the approval of operational feasibility of 10 crude oil distiller units at PT Kilang Pertamina Internasional RU III Plaju. It specifies safety inspections, residual life assessments, and technical standards compliance. The permit applies to equipment used in oil and gas production and requires periodic safety checks and certifications. It lists inspection intervals and conditions for continued operation, emphasizing safety, technical accuracy, and environmental compliance.',
#   'usage': CompletionUsage(completion_tokens=113, prompt_tokens=7587, total_tokens=7700, completion_tokens_details=CompletionTokensDetails(accepted_prediction_tokens=None, audio_tokens=0, reasoning_tokens=0, rejected_prediction_tokens=None), prompt_tokens_details=PromptTokensDetails(audio_tokens=0, cached_tokens=1152))},
#  {'file_path': 'data/folder/KPI_Permits/Sertifikat_PLO_SKPI/PLO RU III/PLO RU III CDU III Plaju Sumsel.pdf',
#   'issue_date': '2023-02-09',
#   'expiration_date': '2026-01-21',
#   'permit_type': 'PLO',
#   'summary': 'The permit approves the operation of 10 units at PT Pertamina Kilang Internasional RU III Plaju. It ensures compliance with safety standards, technical specifications, and environmental regulations for crude distillation operations. Annual and periodic inspections are mandatory. Changes to installations require reporting, and the permit is valid until 2026 unless conditions are breached. The approval signifies readiness for operational use within oil and gas activities.',
#   'usage': CompletionUsage(completion_tokens=110, prompt_tokens=6679, total_tokens=6789, completion_tokens_details=CompletionTokensDetails(accepted_prediction_tokens=None, audio_tokens=0, reasoning_tokens=0, rejected_prediction_tokens=None), prompt_tokens_details=PromptTokensDetails(audio_tokens=0, cached_tokens=1152))},
#  {'file_path': 'data/folder/KPI_Permits/Sertifikat_PLO_SKPI/PLO RU III/PLO RU III RFCCU Plaju Sumsel.pdf',
#   'issue_date': '2023-02-09',
#   'expiration_date': '2026-01-21',
#   'permit_type': 'PLO',
#   'summary': 'The permit grants PT Pertamina Kilang Internasional RU III Plaju approval for the operation of 10 units in its Residue Fluid Catalytic Cracking Unit (RFCCU). It ensures compliance with applicable laws, technical standards, and safety procedures. Comprehensive technical inspections were conducted, and the permit remains valid as long as technical certificates are upheld and regular inspections continue. Conditions include reporting any changes to installations and addressing issues to maintain safety and compliance.',
#   'usage': CompletionUsage(completion_tokens=119, prompt_tokens=7587, total_tokens=7706, completion_tokens_details=CompletionTokensDetails(accepted_prediction_tokens=None, audio_tokens=0, reasoning_tokens=0, rejected_prediction_tokens=None), prompt_tokens_details=PromptTokensDetails(audio_tokens=0, cached_tokens=1152))},
#  {'file_path': 'data/folder/KPI_Permits/Sertifikat_PLO_SKPI/PLO RU III/PLO RU III HVU II Plaju Sumsel.pdf',
#   'issue_date': '2023-02-09',
#   'expiration_date': '2026-01-21',
#   'permit_type': 'PLO',
#   'summary': 'The permit grants approval for operational eligibility of 10 installation units at PT Pertamina Refinery RU III Plaju. It details inspections conducted under compliance with safety and technical standards. Conditions include using certified equipment, reporting modifications, and regular inspections to ensure operational safety. The permit is valid while the equipment complies with technical and environmental standards, requiring reevaluation before the expiration.',
#   'usage': CompletionUsage(completion_tokens=102, prompt_tokens=6679, total_tokens=6781, completion_tokens_details=CompletionTokensDetails(accepted_prediction_tokens=None, audio_tokens=0, reasoning_tokens=0, rejected_prediction_tokens=None), prompt_tokens_details=PromptTokensDetails(audio_tokens=0, cached_tokens=1152))},
#  {'file_path': 'data/folder/KPI_Permits/KKPR_KKPRL/RU III Plaju/KKPR Kilang RU III Area Banyuasi 1.pdf',
#   'issue_date': '2023-04-06',
#   'expiration_date': '2026-04-06',
#   'permit_type': 'KKPR/KKPRL',
#   'summary': 'This permit grants spatial utilization approval for PT Kilang Pertamina International to operate business activities in Sungai Gerong, Banyuasin, Indonesia. It includes industry-related activities in electricity generation and refining fossil fuels. Approved plot covers 4,091,618.65 m², with specific conditions for compliance regarding land use and legal requirements. It is valid for three years from issuance as per risk-based government regulations.',
#   'usage': CompletionUsage(completion_tokens=116, prompt_tokens=4863, total_tokens=4979, completion_tokens_details=CompletionTokensDetails(accepted_prediction_tokens=None, audio_tokens=0, reasoning_tokens=0, rejected_prediction_tokens=None), prompt_tokens_details=PromptTokensDetails(audio_tokens=0, cached_tokens=0))},
#  {'file_path': 'data/folder/KPI_Permits/KKPR_KKPRL/RU III Plaju/KKPR Industri Kimia (KBLI 20117) Area Plaju.pdf',
#   'issue_date': '2024-09-03',
#   'expiration_date': '2027-09-03',
#   'permit_type': 'KKPR/KKPRL',
#   'summary': "The permit approves the usage of land for PT Kilang Pertamina Internasional's industrial chemical operations based on oil, natural gas, and coal. It covers an area of 2,319,232.64 square meters, with operations in South Sumatra. The permit complies with Law No. 5/2021 and is valid for three years. It mandates compliance to regulations, ensures environmental protection, and allows for renewal and further business licensing after the permit's term.",
#   'usage': CompletionUsage(completion_tokens=128, prompt_tokens=3047, total_tokens=3175, completion_tokens_details=CompletionTokensDetails(accepted_prediction_tokens=None, audio_tokens=0, reasoning_tokens=0, rejected_prediction_tokens=None), prompt_tokens_details=PromptTokensDetails(audio_tokens=0, cached_tokens=0))},
#  {'file_path': 'data/folder/KPI_Permits/KKPR_KKPRL/RU III Plaju/KKPR Kilang RU III Area Plaju.pdf',
#   'issue_date': '2023-03-12',
#   'expiration_date': '2026-03-12',
#   'permit_type': 'KKPR/KKPRL',
#   'summary': "This permit approves PT Kilang Pertamina Internasional's activities in utilizing spatial areas for a large-scale business in the oil refinery and processing industry in Palembang, Sumatera Selatan. It provides land usage specifics and coordinates, valid for three years, with conditions such as adherence to laws, proper spatial area utilization, and avoiding activities harmful to the environment or social stability. Renewal or amendment processes may apply to extend scope or land rights associated with the permit.",
#   'usage': CompletionUsage(completion_tokens=123, prompt_tokens=3047, total_tokens=3170, completion_tokens_details=CompletionTokensDetails(accepted_prediction_tokens=None, audio_tokens=0, reasoning_tokens=0, rejected_prediction_tokens=None), prompt_tokens_details=PromptTokensDetails(audio_tokens=0, cached_tokens=0))},
#  {'file_path': 'data/folder/KPI_Permits/KKPR_KKPRL/RU III Plaju/KKPR Industri Kimia (KBLI 20117) Area Banyuasi 1.pdf',
#   'issue_date': '2024-09-03',
#   'expiration_date': '2027-09-03',
#   'permit_type': 'KKPR/KKPRL',
#   'summary': 'The permit approves the utilization of land space for PT Kilang Pertamina Internasional to operate at specified coordinates. It is issued automatically under regulations for large-scale enterprises. The permit is valid for three years, subject to renewal and compliance with laws and regulations. Specific geographical details and conditions for land use, along with obligations for reporting and lawful behavior, are outlined. Violations such as false data provision or legal disputes may result in cancellation.',
#   'usage': CompletionUsage(completion_tokens=120, prompt_tokens=3955, total_tokens=4075, completion_tokens_details=CompletionTokensDetails(accepted_prediction_tokens=None, audio_tokens=0, reasoning_tokens=0, rejected_prediction_tokens=None), prompt_tokens_details=PromptTokensDetails(audio_tokens=0, cached_tokens=0))},
#  {'file_path': 'data/folder/KPI_Permits/KKPR_KKPRL/RU III Plaju/KKPR Perumahan RU III Area Banyuasi 1.pdf',
#   'issue_date': '2024-09-03',
#   'expiration_date': '2027-09-03',
#   'permit_type': 'KKPR/KKPRL',
#   'summary': 'The permit is a business activity spatial use approval issued for PT Kilang Pertamina International, covering land use area of 849,768.35 m² at Sungai Gerong, Banyuasin, Sumatera Selatan. It allows the company to conduct regulated business within the approved coordinates. The permit adheres to 2021 government regulations and is valid for three years. Compliance with conditions and legal provisions in case of issues or disputes is mandatory. Illegal conduct, including false data, may result in permit annulment. Coordination with central and local authorities is required for any inspection or monitoring.',
#   'usage': CompletionUsage(completion_tokens=151, prompt_tokens=6679, total_tokens=6830, completion_tokens_details=CompletionTokensDetails(accepted_prediction_tokens=None, audio_tokens=0, reasoning_tokens=0, rejected_prediction_tokens=None), prompt_tokens_details=PromptTokensDetails(audio_tokens=0, cached_tokens=0))},
#  {'file_path': 'data/folder/KPI_Permits/KKPR_KKPRL/RU III Plaju/KKPR Perumahan RU III Area Plaju.pdf',
#   'issue_date': '2024-09-03',
#   'expiration_date': '2027-09-03',
#   'permit_type': 'KKPR',
#   'summary': "This permit approves PT Kilang Pertamina Internasional's business space utilization in Komperta Plaju, Palembang, South Sumatra. It covers a total area of 1,567,759.73 square meters and includes specific geographic coordinates. The permit is valid for three years and requires compliance with government regulations on business utilization space. It is awarded based on risk-based licensing procedures and mandates the company to uphold legal, environmental, and community considerations in operation.",
#   'usage': CompletionUsage(completion_tokens=122, prompt_tokens=7587, total_tokens=7709, completion_tokens_details=CompletionTokensDetails(accepted_prediction_tokens=None, audio_tokens=0, reasoning_tokens=0, rejected_prediction_tokens=None), prompt_tokens_details=PromptTokensDetails(audio_tokens=0, cached_tokens=0))},
#  {'file_path': 'data/folder/KPI_Permits/KKPR_KKPRL/RU II Dumai & Sei Pakning/KKPR Kilang RU II Sei Pakning.pdf',
#   'issue_date': '2022-07-14',
#   'expiration_date': '2025-07-14',
#   'permit_type': 'KKPR/KKPRL',
#   'summary': "The permit grants PT Kilang Pertamina International approval for land use activities in Riau Province for a large-scale oil refinery business. It is based on the regulations of the Government's Risk-Based Business Licensing framework. It specifies requirements for compliance with further environmental and legal procedures and outlines land area limits and usage as described in the attached coordinates. The permit remains valid for three years from issuance, subject to renewal as per regulations.",
#   'usage': CompletionUsage(completion_tokens=117, prompt_tokens=3047, total_tokens=3164, completion_tokens_details=CompletionTokensDetails(accepted_prediction_tokens=None, audio_tokens=0, reasoning_tokens=0, rejected_prediction_tokens=None), prompt_tokens_details=PromptTokensDetails(audio_tokens=0, cached_tokens=0))},
#  {'file_path': 'data/folder/KPI_Permits/KKPR_KKPRL/RU II Dumai & Sei Pakning/KKPRL RU II Sei Pakning SPL Naphta New.pdf',
#   'issue_date': '2024-08-09',
#   'expiration_date': '2026-08-09',
#   'permit_type': 'KKPR/KKPRL',
#   'summary': 'The permit grants PT Kilang Pertamina Internasional approval for spatial utilization in Selat Malaka, Riau province, to operate SPL Naptha New RU II Sei Pakning facility for petroleum and natural resources. It includes conditions such as complying with environmental guidelines, monitoring by authorities, providing small fishery access, and maintaining marine ecosystem sustainability with social inclusion as part of operations. The permit is valid for two years, requiring compliance with spatial and marine laws of Indonesia while preserving ecological balance and fulfilling reporting obligations.',
#   'usage': CompletionUsage(completion_tokens=134, prompt_tokens=3955, total_tokens=4089, completion_tokens_details=CompletionTokensDetails(accepted_prediction_tokens=None, audio_tokens=0, reasoning_tokens=0, rejected_prediction_tokens=None), prompt_tokens_details=PromptTokensDetails(audio_tokens=0, cached_tokens=0))},
#  {'file_path': 'data/folder/KPI_Permits/KKPR_KKPRL/RU II Dumai & Sei Pakning/KKPR Kilang RU II Dumai.pdf',
#   'issue_date': '2023-04-05',
#   'expiration_date': '2024-02-23',
#   'permit_type': 'KKPR/KKPRL',
#   'summary': 'This permit authorizes PT Kilang Pertamina Internasional to utilize and manage designated land areas for petroleum refining in Dumai, Riau. It complies with Government Regulation No. 6 of 2023, aligning with Cipta Kerja (Job Creation) laws. It includes specific coordinates, area details, and obligations like environmental impact monitoring, land acquisition terms, and adherence to regulatory frameworks. Valid for three years from issuance, the permit can be revoked under conditions such as false data, legal disputes, or violating outlined rules. Continuous compliance and cooperation with government oversight are mandatory.',
#   'usage': CompletionUsage(completion_tokens=149, prompt_tokens=3955, total_tokens=4104, completion_tokens_details=CompletionTokensDetails(accepted_prediction_tokens=None, audio_tokens=0, reasoning_tokens=0, rejected_prediction_tokens=None), prompt_tokens_details=PromptTokensDetails(audio_tokens=0, cached_tokens=0))},
#  {'file_path': 'data/folder/KPI_Permits/KKPR_KKPRL/RU II Dumai & Sei Pakning/KKPRL RU II Sei Pakning SPL Kerosene New.pdf',
#   'issue_date': '2024-08-09',
#   'expiration_date': '2026-08-09',
#   'permit_type': 'KKPR/KKPRL',
#   'summary': "This permit approves the utilization of PT Kilang Pertamina Internasional facilities for industry activities involving SPL kerosene in Riau waters. It ensures operations align with spatial planning rules and environmental conditions, mandates business risk licensing for applicants, and highlights coordination with relevant authorities for oversight. The permit's validity spans two years unless replaced by a formal business licensing document. Obligations include preserving the marine ecosystem, granting fishing access, involving local communities, and addressing emergency infrastructure or further ecological needs.",
#   'usage': CompletionUsage(completion_tokens=129, prompt_tokens=3955, total_tokens=4084, completion_tokens_details=CompletionTokensDetails(accepted_prediction_tokens=None, audio_tokens=0, reasoning_tokens=0, rejected_prediction_tokens=None), prompt_tokens_details=PromptTokensDetails(audio_tokens=0, cached_tokens=0))},
#  {'file_path': 'data/folder/KPI_Permits/KKPR_KKPRL/RU II Dumai & Sei Pakning/KKPRL RU II Sei Pakning SPL Naphta Eksisting.pdf',
#   'issue_date': '2024-07-26',
#   'expiration_date': '2026-07-26',
#   'permit_type': 'KKPR/KKPRL',
#   'summary': 'The permit approves the utilization of marine space for PT Kilang Pertamina Internasional for activities related to the oil and gas industry at SPL Naptha Eksisting RU II Sei Pakning. Conditions include compliance with spatial planning, environmental standards, and reporting requirements. Coordination, maps, and obligations pertaining to conservation and stakeholder engagement are integral to the implementation.',
#   'usage': CompletionUsage(completion_tokens=102, prompt_tokens=3955, total_tokens=4057, completion_tokens_details=CompletionTokensDetails(accepted_prediction_tokens=None, audio_tokens=0, reasoning_tokens=0, rejected_prediction_tokens=None), prompt_tokens_details=PromptTokensDetails(audio_tokens=0, cached_tokens=0))},
#  {'file_path': 'data/folder/KPI_Permits/KKPR_KKPRL/RU II Dumai & Sei Pakning/KKPRL RU II Sei Pakning SPL Crude Oil Eksisting.pdf',
#   'issue_date': '2024-07-26',
#   'expiration_date': '2026-07-26',
#   'permit_type': 'KKPR/KKPRL',
#   'summary': "The permit approves PT Kilang Pertamina Internasional's usage of maritime space for SPL Crude Oil Eksisting RU II Sei Pakning in Selat Malaka, Riau. It specifies location coordinates, dimensions, and depth for operational activities. Conditions include compliance with spatial planning, submission of environmental risk management permits, and adherence to national regulations. The permit mandates regular reporting, environmental conservation measures, and contributions to local community welfare. It emphasizes the coexistence of activities with local marine life and navigation, as well as the importance of preventing pollution and ensuring marine ecosystem resilience.",
#   'usage': CompletionUsage(completion_tokens=147, prompt_tokens=3955, total_tokens=4102, completion_tokens_details=CompletionTokensDetails(accepted_prediction_tokens=None, audio_tokens=0, reasoning_tokens=0, rejected_prediction_tokens=None), prompt_tokens_details=PromptTokensDetails(audio_tokens=0, cached_tokens=0))},
#  {'file_path': 'data/folder/KPI_Permits/KKPR_KKPRL/RU II Dumai & Sei Pakning/KKPRL RU II Sei Pakning SPL ADO Eksisting.pdf',
#   'issue_date': '2024-07-30',
#   'expiration_date': '2026-07-30',
#   'permit_type': 'KKPR/KKPRL',
#   'summary': 'This permit grants PT Kilang Pertamina Internasional authorization for industrial activities involving fuel refining and processing offshore in Riau, Selat Malaka. It ensures compliance with spatial planning and environmental laws, mandates monitoring by authorities, and sets obligations for ecological preservation, community engagement, and providing small fishermen access. Valid for two years, this document outlines the rights, duties, and coordinates for the operational site, emphasizing sustainable use and adherence to regulations during the operational period.',
#   'usage': CompletionUsage(completion_tokens=125, prompt_tokens=3955, total_tokens=4080, completion_tokens_details=CompletionTokensDetails(accepted_prediction_tokens=None, audio_tokens=0, reasoning_tokens=0, rejected_prediction_tokens=None), prompt_tokens_details=PromptTokensDetails(audio_tokens=0, cached_tokens=0))},
#  {'file_path': 'data/folder/KPI_Permits/KKPR_KKPRL/RU II Dumai & Sei Pakning/KKPRL RU II Sei Pakning Area Jetty.pdf',
#   'issue_date': '2024-07-26',
#   'expiration_date': '2026-07-26',
#   'permit_type': 'KKPRL',
# ...
#   'usage': CompletionUsage(completion_tokens=136, prompt_tokens=4863, total_tokens=4999, completion_tokens_details=CompletionTokensDetails(accepted_prediction_tokens=None, audio_tokens=0, reasoning_tokens=0, rejected_prediction_tokens=None), prompt_tokens_details=PromptTokensDetails(audio_tokens=0, cached_tokens=0))},
#  {'file_path': 'data/folder/KPI_Permits/KKPR_KKPRL/RU VI Balongan/KKPR Perumahan RU VI Balongan.pdf',
#   'issue_date': '2024-03-20',
#   'expiration_date': '2024-03-21',
#   'permit_type': 'PLO',
#   'summary': "This permit issued by the Indonesian government outlines operational authorization for PT Kilang Pertamina Internasional. It states compliance requirements with Indonesia's KBLI code 68111 for real estate activities, including reporting obligations, spatial development plans, and adherence to Legal Norms, Standards, Procedures, and Criteria (NSPK). Validity lasts as long as business activities are performed. It includes mandatory reports and spatial plans confirmed by the regional government of Indramayu.",
#   'usage': CompletionUsage(completion_tokens=119, prompt_tokens=2139, total_tokens=2258, completion_tokens_details=CompletionTokensDetails(accepted_prediction_tokens=None, audio_tokens=0, reasoning_tokens=0, rejected_prediction_tokens=None), prompt_tokens_details=PromptTokensDetails(audio_tokens=0, cached_tokens=0))},
#  {'file_path': 'data/folder/KPI_Permits/KKPR_KKPRL/RU VI Balongan/KKPRL RU VI Balongan SPL No. 11 to SPM 17.500 DWT.pdf',
#   'issue_date': '2024-07-23',
#   'expiration_date': '2026-07-23',
#   'permit_type': 'KKPR/KKPRL',
#   'summary': "This permit approves PT Kilang Pertamina Internasional for the utilization of maritime space in Jawa Barat's coastal waters to develop a submarine pipeline for hydrocarbon transportation. It specifies the approved pipeline coordinates and depth while mandating compliance with marine conservation regulations. The permit is valid for two years and requires the grantee to preserve ecosystems, allow passage for small fishers, and ensure minimal environmental impact. Any installation modifications or dismantling post-permit expiry should align with national spatial planning rules.",
#   'usage': CompletionUsage(completion_tokens=129, prompt_tokens=3955, total_tokens=4084, completion_tokens_details=CompletionTokensDetails(accepted_prediction_tokens=None, audio_tokens=0, reasoning_tokens=0, rejected_prediction_tokens=None), prompt_tokens_details=PromptTokensDetails(audio_tokens=0, cached_tokens=0))},
#  {'file_path': 'data/folder/KPI_Permits/KKPR_KKPRL/RU VI Balongan/KKPRL RU VI Balongan Jetty, SPM dan Area Pengerukan.pdf',
#   'issue_date': '2024-07-23',
#   'expiration_date': '2026-07-23',
#   'permit_type': 'KKPR/KKPRL',
#   'summary': 'This permit grants PT Kilang Pertamina Internasional the approval for sea space utilization, specifically for the operation of Jetty and Single Point Mooring RU VI Balongan in the Jawa Barat region. It covers 30.57 hectares with specified coordinates. Conditions include environmental preservation, adherence to sea conservation laws, and access for the public and fishermen. Valid for two years, the permit establishes responsibilities like annual reporting, compliance with legal standards, and proactive community involvement within the activity area.',
#   'usage': CompletionUsage(completion_tokens=129, prompt_tokens=9403, total_tokens=9532, completion_tokens_details=CompletionTokensDetails(accepted_prediction_tokens=None, audio_tokens=0, reasoning_tokens=0, rejected_prediction_tokens=None), prompt_tokens_details=PromptTokensDetails(audio_tokens=0, cached_tokens=0))},
#  {'file_path': 'data/folder/KPI_Permits/KKPR_KKPRL/RU VI Balongan/KKPR Kilang RU VI Balongan.pdf',
#   'issue_date': '2023-03-17',
#   'expiration_date': '2026-03-17',
#   'permit_type': 'KKPR/KKPRL',
#   'summary': 'This permit approves the suitability of spatial utilization activities for PT Kilang Pertamina International to conduct business operations. Located in Indramayu, West Java, the permit specifies an industrial scope for petroleum refining and production. The permit is valid for three years from the issuance date and outlines compliance with regulations, land usage rights, and operational boundaries. Conditions include adherence to further permits, land ownership proofs, risk-based environmental controls, and government oversight. The permit may be revoked due to false data, legal disputes, environmental or social harm, and regulatory non-compliance.',
#   'usage': CompletionUsage(completion_tokens=144, prompt_tokens=3955, total_tokens=4099, completion_tokens_details=CompletionTokensDetails(accepted_prediction_tokens=None, audio_tokens=0, reasoning_tokens=0, rejected_prediction_tokens=None), prompt_tokens_details=PromptTokensDetails(audio_tokens=0, cached_tokens=0))},
#  {'file_path': 'data/folder/KPI_Permits/KKPR_KKPRL/RU VI Balongan/KKPRL RU VI Balongan SPL No. 4 to SPM 165.000 DWT.pdf',
#   'issue_date': '2024-07-23',
#   'expiration_date': '2026-07-23',
#   'permit_type': 'KKPR/KKPRL',
#   'summary': "This permit approves PT Kilang Pertamina Internasional's use of maritime space for the development and operation of Submarine Pipeline Number 4 in RU VI Balongan. It outlines coordinates in Jakarta, Jawa Barat for activities involving oil refining and industry. It includes specific obligations such as maintaining environmental standards, granting access to fishermen, and reporting to authorities about any installations or developments. The permit is valid for two years from the issue date and provides rights and responsibilities for the holder within the scope stated.",
#   'usage': CompletionUsage(completion_tokens=131, prompt_tokens=3955, total_tokens=4086, completion_tokens_details=CompletionTokensDetails(accepted_prediction_tokens=None, audio_tokens=0, reasoning_tokens=0, rejected_prediction_tokens=None), prompt_tokens_details=PromptTokensDetails(audio_tokens=0, cached_tokens=0))},
#  {'file_path': 'data/folder/KPI_Permits/KKPR_KKPRL/RU VI Balongan/KKPRL RU VI Balongan SPL No. 5 to SPM 165.000 DWT.pdf',
#   'issue_date': '2024-07-23',
#   'expiration_date': '2026-07-23',
#   'permit_type': 'KKPR/KKPRL',
#   'summary': 'This permit grants PT Kilang Pertamina Internasional approval to utilize marine space for the Submarine Pipeline Number 5 (165,000 DWT) in the Java Sea, with a length of 15.06 km and depth of 24 meters. It defines obligations to environmental preservation, society engagement, and marine ecosystem protection while allowing business activities within specified coordinates. The permit is valid for two years and subject to compliance with detailed terms, including reporting and collaboration with conservation initiatives.',
#   'usage': CompletionUsage(completion_tokens=129, prompt_tokens=3955, total_tokens=4084, completion_tokens_details=CompletionTokensDetails(accepted_prediction_tokens=None, audio_tokens=0, reasoning_tokens=0, rejected_prediction_tokens=None), prompt_tokens_details=PromptTokensDetails(audio_tokens=0, cached_tokens=0))},
#  {'file_path': 'data/folder/KPI_Permits/KKPR_KKPRL/RU VI Balongan/KKPRL RU VI Balongan - SPM & SPL 35.000 DWT dan Dumping Area.pdf',
#   'issue_date': '2024-06-28',
#   'expiration_date': '2026-06-28',
#   'permit_type': 'KKPR/KKPRL',
#   'summary': 'The permit authorizes PT Kilang Pertamina Internasional to utilize marine space for oil refinery operations, specifically at SPM and SPL 35000 DWT RU VI Balongan and Dumping Area in Jawa Barat. It expands over 10.98 hectares in Laut Jawa, specifying coordinates. Adherence to environmental sustainability and responsibilities, such as providing access for local fishermen, are mandated. The permit is valid for two years with strict conditions including reporting, preventing pollution, and contributing to marine conservation.',
#   'usage': CompletionUsage(completion_tokens=132, prompt_tokens=6679, total_tokens=6811, completion_tokens_details=CompletionTokensDetails(accepted_prediction_tokens=None, audio_tokens=0, reasoning_tokens=0, rejected_prediction_tokens=None), prompt_tokens_details=PromptTokensDetails(audio_tokens=0, cached_tokens=0))},
#  {'file_path': 'data/folder/KPI_Permits/KKPR_KKPRL/RU V Balikpapan/KKPRL Pengerukan Alur Pelayaran RU V Balikpapan.pdf',
#   'issue_date': '2024-06-27',
#   'expiration_date': '2026-06-27',
#   'permit_type': 'KKPRL',
#   'summary': 'The permit approves the utilization of sea space for industrial activities, particularly for oil refinery and extraction in Selat Makassar. The space covers 10.19 ha located near Kalimantan Timur. It delineates responsibilities such as prioritizing environmental conservation and enabling access for local communities. It is valid for two years under specific monitoring and reporting obligations, including submission of annual reports and adhering to governmental regulations for coastal conservation and safety.',
#   'usage': CompletionUsage(completion_tokens=115, prompt_tokens=3955, total_tokens=4070, completion_tokens_details=CompletionTokensDetails(accepted_prediction_tokens=None, audio_tokens=0, reasoning_tokens=0, rejected_prediction_tokens=None), prompt_tokens_details=PromptTokensDetails(audio_tokens=0, cached_tokens=0))},
#  {'file_path': 'data/folder/KPI_Permits/KKPR_KKPRL/RU V Balikpapan/KKPR Kilang RU V Balikpapan.pdf',
#   'issue_date': '2023-03-27',
#   'expiration_date': '2026-03-27',
#   'permit_type': 'KKPR/KKPRL',
#   'summary': 'This permit is issued to PT Kilang Pertamina Internasional for spatial utilization activities related to large-scale industrial businesses. It covers refinery operations in Balikpapan, East Kalimantan. Conditions include strict compliance with regulations and being valid for three years from the issuance date. The permit supports business risk-based licensing requirements governed by relevant laws.',
#   'usage': CompletionUsage(completion_tokens=101, prompt_tokens=7587, total_tokens=7688, completion_tokens_details=CompletionTokensDetails(accepted_prediction_tokens=None, audio_tokens=0, reasoning_tokens=0, rejected_prediction_tokens=None), prompt_tokens_details=PromptTokensDetails(audio_tokens=0, cached_tokens=0))},
#  {'file_path': 'data/folder/KPI_Permits/KKPR_KKPRL/RU IV Cilacap/KKPR Kilang RU IV Cilacap KBLI 19211.pdf',
#   'issue_date': '2022-11-17',
#   'expiration_date': '2024-02-23',
#   'permit_type': 'KKPRL',
#   'summary': 'This permit confirms the suitability of space utilization activities for PT Kilang Pertamina Internasional in Cilacap, Jawa Tengah. It specifies the approved land area (3,844,714.57 m²) and its classification within an industrial zone. Conditions for base coefficients, road functionality, and building setbacks are detailed, ensuring compliance with spatial planning regulations under Perpu No. 75 Tahun 2021. The permit holder must follow governmental regulations and may apply for further business operational permits.',
#   'usage': CompletionUsage(completion_tokens=128, prompt_tokens=4863, total_tokens=4991, completion_tokens_details=CompletionTokensDetails(accepted_prediction_tokens=None, audio_tokens=0, reasoning_tokens=0, rejected_prediction_tokens=None), prompt_tokens_details=PromptTokensDetails(audio_tokens=0, cached_tokens=0))},
#  {'file_path': 'data/folder/KPI_Permits/KKPR_KKPRL/RU IV Cilacap/KKPR RU IV Cilacap KBLI 20117.pdf',
#   'issue_date': '2024-03-22',
#   'expiration_date': '2024-03-25',
#   'permit_type': 'KKPR',
#   'summary': 'This permit is for PT Kilang Pertamina Internasional, allowing spatial utilization for industrial activities in Cilacap, Jawa Tengah. The permit confirms compliance with spatial planning regulations and authorizes industrial operations with conditions specified, including the areas classified under industrial zones, geographical coordinates, and building functions. It also mandates adherence to national laws and regulations while granting authorization to proceed with business-based risk permits after obtaining this confirmation.',
#   'usage': CompletionUsage(completion_tokens=111, prompt_tokens=7587, total_tokens=7698, completion_tokens_details=CompletionTokensDetails(accepted_prediction_tokens=None, audio_tokens=0, reasoning_tokens=0, rejected_prediction_tokens=None), prompt_tokens_details=PromptTokensDetails(audio_tokens=0, cached_tokens=0))},
#  {'file_path': 'data/folder/KPI_Permits/KKPR_KKPRL/RU IV Cilacap/KKPR RU IV Cilacap KBLI 20115.pdf',
#   'issue_date': '2024-03-22',
#   'expiration_date': '2024-03-22',
#   'permit_type': 'KKPR',
#   'summary': 'This permit confirms the suitability of land use activities under Perppu No. 6 Tahun 2023 and Perppu No. 75 Tahun 2021. Issued to PT Kilang Pertamina Internasional for activities in chemical and industrial use. It specifies requirements such as adherence to geographical coordinates, zoning regulations, land usage, and compliance with applicable laws. The permit is mandatory for applying for additional business permits and undertaking operations strictly within permitted locations.',
#   'usage': CompletionUsage(completion_tokens=119, prompt_tokens=7587, total_tokens=7706, completion_tokens_details=CompletionTokensDetails(accepted_prediction_tokens=None, audio_tokens=0, reasoning_tokens=0, rejected_prediction_tokens=None), prompt_tokens_details=PromptTokensDetails(audio_tokens=0, cached_tokens=0))},
#  {'file_path': 'data/folder/KPI_Permits/KKPR_KKPRL/RU IV Cilacap/KKPR 86901 - Griya Sehat RU IV Cilacap.pdf',
#   'issue_date': '2024-05-21',
#   'expiration_date': '2025-05-21',
#   'permit_type': 'KKPR',
#   'summary': 'This permit confirms spatial utilization compliance for business activities of PT Kilang Pertamina Internasional based on the Government Regulation No. 6 of 2023 and Perpub No. 75 of 2021. It facilitates the business at Pertamina RU IV Cilacap with specified geographical compliance and land area. The permit is valid for the allocated coordinates and is subject to monitoring by governmental institutions. Spatial utilization must comply with the applicable regulations including adherence to zoning parameters such as KKOP territories.',
#   'usage': CompletionUsage(completion_tokens=127, prompt_tokens=5771, total_tokens=5898, completion_tokens_details=CompletionTokensDetails(accepted_prediction_tokens=None, audio_tokens=0, reasoning_tokens=0, rejected_prediction_tokens=None), prompt_tokens_details=PromptTokensDetails(audio_tokens=0, cached_tokens=0))},
#  {'file_path': 'data/folder/KPI_Permits/KKPR_KKPRL/RU IV Cilacap/KKPR KBLI 86105 - Klinik RU IV Cilacap.pdf',
#   'issue_date': '2024-05-21',
#   'expiration_date': '2025-05-21',
#   'permit_type': 'KKPR/KKPRL',
#   'summary': "The permit confirms the utilization of spatial planning for PT Kilang Pertamina Internasional's industrial activities at the Pertamina RU IV Cilacap site. It includes coordinates, land area, zoning requirements, building coefficients, and environmental conditions. The confirmed activities align with legal regulations and require adherence to zoning standards, such as classifications for primary and secondary road functions. Business operations must comply with the stipulated scope and laws.",
#   'usage': CompletionUsage(completion_tokens=115, prompt_tokens=5771, total_tokens=5886, completion_tokens_details=CompletionTokensDetails(accepted_prediction_tokens=None, audio_tokens=0, reasoning_tokens=0, rejected_prediction_tokens=None), prompt_tokens_details=PromptTokensDetails(audio_tokens=0, cached_tokens=0))}]

# %%
import json

# Convert usage objects to dictionaries for JSON serialization
def serialize_metadata(metadata_list):
    serialized = []
    for item in metadata_list:
        serialized_item = item.copy()
        if 'usage' in serialized_item and serialized_item['usage'] is not None:
            serialized_item['usage'] = serialized_item['usage'].model_dump()
        serialized.append(serialized_item)
    return serialized

# Write metadata_result to JSON file
output_file = "data/metadata_result.json"

with open(output_file, 'w', encoding='utf-8') as f:
    json.dump(serialize_metadata(metadata_result), f, indent=2, ensure_ascii=False)

print(f"Metadata saved to {output_file}")
# Out:
# Metadata saved to data/metadata_result.json
